# %% [markdown]
# # GAS STATIONS IN MEXICO
#
# ## Markdown (Carlos)
#
# •	¿Existe una relación significativa entre el rating y el precio?
# •	¿Existe una relación significativa entre la ubicación geográfica y el precio?
# •	¿Los rating cero tienen una correlación con las zonas geográficas?
# •	¿Existe una relación significativa entre tipo de gasolina y ubicación?

# %%
# Dependencies
import pandas as pd
import numpy as np
from numpy import NaN
import matplotlib.pyplot as plt
import requests
import json
from config import gkey

# %%
def listToString(s):  
    
    # initialize an empty string 
    str1 = " " 
    
    # return string   
    return (str1.join(s))

# %% [markdown]
# # 1. Use pandas to clean and format your dataset(s)
#
# # 2. Create a Jupyter Notebook describing the data exploration and cleanup process

# %%
# Extracting Data from CSV to Jupyter-Notebook
prices_file = "Resources/prices.csv"
places_file = "Resources/places.csv"
prices_df = pd.read_csv(prices_file)
places_df = pd.read_csv(places_file)

# %%
# Cleaning Columns on Prices DataFrame
prices_df = prices_df.drop('places', axis = 1)
prices_df = prices_df.drop('place', axis = 1)
prices_df
# Out:
#        place_id  gas_price     type
# 0       11703.0      18.69  regular
# 1           NaN      19.69  premium
# 2       11702.0      18.19  regular
# 3           NaN      19.79  premium
# 4           NaN      18.25   diesel
# ...         ...        ...      ...
# 33210       NaN      19.59  premium
# 33211       NaN      18.60   diesel
# 33212    2807.0      17.99  regular
# 33213    2807.0      19.99  premium
# 33214    2807.0      18.69   diesel
#
# [33215 rows x 3 columns]

# %%
# Creating a column to replace NaNs with Places_ID
Place_ID = prices_df['place_id'].fillna(method='ffill')
# Adding Column to existing prices DataFrame
prices_df['Place_ID'] = Place_ID
# Eliminating original place_id from DataFrame
prices_df = prices_df.drop('place_id', axis = 1)
# Rearrange DataFrame
prices_df = prices_df[['Place_ID','gas_price','type']]
# Rename Place_ID
prices_df.columns = ['_place_id', 'gas_price','type']
prices_df
# Out:
#        _place_id  gas_price     type
# 0        11703.0      18.69  regular
# 1        11703.0      19.69  premium
# 2        11702.0      18.19  regular
# 3        11702.0      19.79  premium
# 4        11702.0      18.25   diesel
# ...          ...        ...      ...
# 33210    11704.0      19.59  premium
# 33211    11704.0      18.60   diesel
# 33212     2807.0      17.99  regular
# 33213     2807.0      19.99  premium
# 33214     2807.0      18.69   diesel
#
# [33215 rows x 3 columns]

# %%
# Merging DataFrames and Renaming column _place_id
Gas_Stations_df = pd.merge(places_df, prices_df, on="_place_id")
Gas_Stations_df = Gas_Stations_df.rename(columns={"_place_id":"place_id",
                                                 "location/x":"Lng",
                                                 "location/y":"Lat",
                                                 "type":"gas type"})
Gas_Stations_df
# Out:
#                                               name                cre_id  \
# 0       ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.    PL/658/EXP/ES/2015
# 1       ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.    PL/658/EXP/ES/2015
# 2       ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.    PL/658/EXP/ES/2015
# 3                     DIGEPE, S.A. DE C.V. (07356)    PL/902/EXP/ES/2015
# 4                     DIGEPE, S.A. DE C.V. (07356)    PL/902/EXP/ES/2015
# ...                                            ...                   ...
# 33210  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV  PL/23508/EXP/ES/2020
# 33211  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV  PL/23508/EXP/ES/2020
# 33212                      JAGREGAS 2 S.A. DE C.V.  PL/23510/EXP/ES/2020
# 33213                      JAGREGAS 2 S.A. DE C.V.  PL/23510/EXP/ES/2020
# 33214                      JAGREGAS 2 S.A. DE C.V.  PL/23510/EXP/ES/2020
#
#              Lng       Lat  place_id  gas_price gas type
# 0     -116.92140  32.47641      2039      17.39  regular
# 1     -116.92140  32.47641      2039      19.35  premium
# 2     -116.92140  32.47641      2039      18.45   diesel
# 3      -99.74484  20.30370      2040      18.65  regular
# 4      -99.74484  20.30370      2040      18.99  premium
# ...          ...       ...       ...        ...      ...
# 33210 -103.40990  22.83751     27300      18.59  premium
# 33211 -103.40990  22.83751     27300      18.89   diesel
# 33212 -100.41290  20.67198     27304      16.99  regular
# 33213 -100.41290  20.67198     27304      17.30  premium
# 33214 -100.41290  20.67198     27304      17.41   diesel
#
# [33215 rows x 7 columns]

# %%
gas_id = Gas_Stations_df.drop_duplicates(subset="place_id")
gas_id = gas_id.reset_index(drop=False)
gas_id
# Out:
#        index                                         name  \
# 0          0   ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.
# 1          3                 DIGEPE, S.A. DE C.V. (07356)
# 2          6                       DIAZ GAS, S.A. DE C.V.
# 3          8                  COMBU-EXPRESS, S.A. DE C.V.
# 4         11                       PETROMAX, S.A. DE C.V.
# ...      ...                                          ...
# 12455  33200                  MEGA GASOLINERAS S.A DE C.V
# 12456  33203          GRUPO ENERGETICO GUDE, S.A. DE C.V.
# 12457  33206                  MEGA GASOLINERAS S.A DE C.V
# 12458  33209  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV
# 12459  33212                      JAGREGAS 2 S.A. DE C.V.
#
#                      cre_id        Lng       Lat  place_id  gas_price gas type
# 0        PL/658/EXP/ES/2015 -116.92140  32.47641      2039      17.39  regular
# 1        PL/902/EXP/ES/2015  -99.74484  20.30370      2040      18.65  regular
# 2        PL/760/EXP/ES/2015 -106.45140  31.71947      2041      12.82  regular
# 3        PL/825/EXP/ES/2015 -103.30420  20.71413      2042      18.64  regular
# 4        PL/585/EXP/ES/2015  -98.29977  26.03787      2043      14.79  regular
# ...                     ...        ...       ...       ...        ...      ...
# 12455  PL/23515/EXP/ES/2020 -101.34460  20.72499     27295      18.79  regular
# 12456  PL/23507/EXP/ES/2020 -102.88500  23.16178     27298      18.15  regular
# 12457  PL/23513/EXP/ES/2020 -101.36640  20.68246     27299      18.25  regular
# 12458  PL/23508/EXP/ES/2020 -103.40990  22.83751     27300      17.89  regular
# 12459  PL/23510/EXP/ES/2020 -100.41290  20.67198     27304      16.99  regular
#
# [12460 rows x 8 columns]

# %%
gas_id["Rating"] = ""
gas_id["User Ratings"] ="" 
gas_id["Google_Name"] = ""
gas_id["Address"]= ""
gas_id["Types"]= ""
gas_id.head()
# Out:
#    index                                        name              cre_id  \
# 0      0  ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.  PL/658/EXP/ES/2015
# 1      3                DIGEPE, S.A. DE C.V. (07356)  PL/902/EXP/ES/2015
# 2      6                      DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015
# 3      8                 COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015
# 4     11                      PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015
#
#          Lng       Lat  place_id  gas_price gas type Rating User Ratings  \
# 0 -116.92140  32.47641      2039      17.39  regular
# 1  -99.74484  20.30370      2040      18.65  regular
# 2 -106.45140  31.71947      2041      12.82  regular
# 3 -103.30420  20.71413      2042      18.64  regular
# 4  -98.29977  26.03787      2043      14.79  regular
#
#   Google_Name Address Types
# 0
# 1
# 2
# 3
# 4

# %%
params = {
    "rankby":"distance",
    "type": "gas_station",
    "keyword": "fuel station",
    "key": gkey    
}

# Hit the Google Places API for each city's coordinates.
url_base = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
carlos_df = gas_id.iloc[0:2491,:]
rodrigo_df = gas_id.iloc[2491:4983,:]
pau_df = gas_id.iloc[4983:7475,:]
eduardo_df = gas_id.iloc[7475:9967,:]
sam_df =  gas_id.iloc[9967:12460,:]

# %%
# Store the first Hotel result into the DataFrame.
json_list = []
for index, row in pau_df.iterrows():
    lat=row["Lat"]
    lon=row["Lng"]
        
    params["location"] = f"{lat},{lon}"
    
    print(f"Results for observation: {index}")
    try:
        response = requests.get(url_base, params=params).json()
        pau_df.loc[index, "Rating"] = response["results"][0]["rating"]
        pau_df.loc[index, "User Ratings"] = response["results"][0]["user_ratings_total"]
        pau_df.loc[index, "Google_Name"] = response["results"][0]["name"]
        pau_df.loc[index, "Address"] = response["results"][0]["vicinity"]
        string = response["results"][0]["types"]
        string_value = listToString(string)
        string_value = string_value.replace(" ",", ")
        pau_df.loc[index, "Types"] = string_value
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

# To storage the requests
        json_list.append(response)
# Out:
# Results for observation: 4983
# C:\Users\Carlo\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Results for observation: 4984
# Results for observation: 4985
# Results for observation: 4986
# Results for observation: 4987
# Results for observation: 4988
# Results for observation: 4989
# Results for observation: 4990
# Results for observation: 4991
# Results for observation: 4992
# Results for observation: 4993
# Results for observation: 4994
# Results for observation: 4995
# Results for observation: 4996
# Results for observation: 4997
# Results for observation: 4998
# Results for observation: 4999
# Results for observation: 5000
# Results for observation: 5001
# Results for observation: 5002
# Results for observation: 5003
# Results for observation: 5004
# Results for observation: 5005
# Results for observation: 5006
# Results for observation: 5007
# Results for observation: 5008
# Results for observation: 5009
# Results for observation: 5010
# Results for observation: 5011
# Results for observation: 5012
# Results for observation: 5013
# Results for observation: 5014
# Results for observation: 5015
# Results for observation: 5016
# Results for observation: 5017
# Results for observation: 5018
# Results for observation: 5019
# Results for observation: 5020
# Results for observation: 5021
# Results for observation: 5022
# Results for observation: 5023
# Results for observation: 5024
# Results for observation: 5025
# Results for observation: 5026
# Results for observation: 5027
# Results for observation: 5028
# Results for observation: 5029
# Results for observation: 5030
# Results for observation: 5031
# Results for observation: 5032
# Results for observation: 5033
# Results for observation: 5034
# Results for observation: 5035
# Results for observation: 5036
# Results for observation: 5037
# Results for observation: 5038
# Results for observation: 5039
# Results for observation: 5040
# Results for observation: 5041
# Results for observation: 5042
# Results for observation: 5043
# Results for observation: 5044
# Results for observation: 5045
# Results for observation: 5046
# Results for observation: 5047
# Results for observation: 5048
# Results for observation: 5049
# Results for observation: 5050
# Results for observation: 5051
# Results for observation: 5052
# Results for observation: 5053
# Results for observation: 5054
# Results for observation: 5055
# Results for observation: 5056
# Results for observation: 5057
# Results for observation: 5058
# Results for observation: 5059
# Results for observation: 5060
# Results for observation: 5061
# Results for observation: 5062
# Results for observation: 5063
# Results for observation: 5064
# Results for observation: 5065
# Results for observation: 5066
# Results for observation: 5067
# Results for observation: 5068
# Results for observation: 5069
# Results for observation: 5070
# Results for observation: 5071
# Results for observation: 5072
# Results for observation: 5073
# Results for observation: 5074
# Results for observation: 5075
# Results for observation: 5076
# Results for observation: 5077
# Results for observation: 5078
# Results for observation: 5079
# Results for observation: 5080
# Results for observation: 5081
# Results for observation: 5082
# Results for observation: 5083
# Results for observation: 5084
# Results for observation: 5085
# Results for observation: 5086
# Results for observation: 5087
# Results for observation: 5088
# Results for observation: 5089
# Results for observation: 5090
# Results for observation: 5091
# Results for observation: 5092
# Results for observation: 5093
# Results for observation: 5094
# Results for observation: 5095
# Results for observation: 5096
# Results for observation: 5097
# Results for observation: 5098
# Results for observation: 5099
# Results for observation: 5100
# Results for observation: 5101
# Results for observation: 5102
# Results for observation: 5103
# Results for observation: 5104
# Results for observation: 5105
# Results for observation: 5106
# Results for observation: 5107
# Results for observation: 5108
# Results for observation: 5109
# Results for observation: 5110
# Results for observation: 5111
# Results for observation: 5112
# Results for observation: 5113
# Results for observation: 5114
# Results for observation: 5115
# Results for observation: 5116
# Results for observation: 5117
# Results for observation: 5118
# Results for observation: 5119
# Results for observation: 5120
# Results for observation: 5121
# Results for observation: 5122
# Results for observation: 5123
# Results for observation: 5124
# Results for observation: 5125
# Results for observation: 5126
# Results for observation: 5127
# Results for observation: 5128
# Results for observation: 5129
# Results for observation: 5130
# Results for observation: 5131
# Results for observation: 5132
# Results for observation: 5133
# Results for observation: 5134
# Results for observation: 5135
# Results for observation: 5136
# Results for observation: 5137
# Results for observation: 5138
# Results for observation: 5139
# Results for observation: 5140
# Results for observation: 5141
# Results for observation: 5142
# Results for observation: 5143
# Results for observation: 5144
# Results for observation: 5145
# Results for observation: 5146
# Results for observation: 5147
# Results for observation: 5148
# Results for observation: 5149
# Results for observation: 5150
# Results for observation: 5151
# Results for observation: 5152
# Results for observation: 5153
# Results for observation: 5154
# Results for observation: 5155
# Results for observation: 5156
# Results for observation: 5157
# Results for observation: 5158
# Results for observation: 5159
# Results for observation: 5160
# Results for observation: 5161
# Results for observation: 5162
# Results for observation: 5163
# Results for observation: 5164
# Results for observation: 5165
# Results for observation: 5166
# Results for observation: 5167
# Results for observation: 5168
# Results for observation: 5169
# Results for observation: 5170
# Results for observation: 5171
# Results for observation: 5172
# Results for observation: 5173
# Results for observation: 5174
# Results for observation: 5175
# Results for observation: 5176
# Results for observation: 5177
# Results for observation: 5178
# Results for observation: 5179
# Results for observation: 5180
# Results for observation: 5181
# Results for observation: 5182
# Results for observation: 5183
# Results for observation: 5184
# Results for observation: 5185
# Results for observation: 5186
# Results for observation: 5187
# Results for observation: 5188
# Results for observation: 5189
# Results for observation: 5190
# Results for observation: 5191
# Results for observation: 5192
# Results for observation: 5193
# Results for observation: 5194
# Results for observation: 5195
# Results for observation: 5196
# Results for observation: 5197
# Results for observation: 5198
# Results for observation: 5199
# Results for observation: 5200
# Missing field/result... skipping.
# Results for observation: 5201
# Results for observation: 5202
# Results for observation: 5203
# Results for observation: 5204
# Results for observation: 5205
# Results for observation: 5206
# Results for observation: 5207
# Results for observation: 5208
# Results for observation: 5209
# Results for observation: 5210
# Results for observation: 5211
# Results for observation: 5212
# Results for observation: 5213
# Results for observation: 5214
# Results for observation: 5215
# Results for observation: 5216
# Results for observation: 5217
# Results for observation: 5218
# Results for observation: 5219
# Results for observation: 5220
# Results for observation: 5221
# Results for observation: 5222
# Results for observation: 5223
# Results for observation: 5224
# Results for observation: 5225
# Results for observation: 5226
# Results for observation: 5227
# Results for observation: 5228
# Results for observation: 5229
# Results for observation: 5230
# Results for observation: 5231
# Results for observation: 5232
# Results for observation: 5233
# Results for observation: 5234
# Results for observation: 5235
# Results for observation: 5236
# Results for observation: 5237
# Results for observation: 5238
# Results for observation: 5239
# Results for observation: 5240
# Results for observation: 5241
# Results for observation: 5242
# Results for observation: 5243
# Results for observation: 5244
# Results for observation: 5245
# Results for observation: 5246
# Results for observation: 5247
# Results for observation: 5248
# Results for observation: 5249
# Results for observation: 5250
# Results for observation: 5251
# Results for observation: 5252
# Results for observation: 5253
# Results for observation: 5254
# Results for observation: 5255
# Results for observation: 5256
# Results for observation: 5257
# Results for observation: 5258
# Results for observation: 5259
# Results for observation: 5260
# Results for observation: 5261
# Results for observation: 5262
# Results for observation: 5263
# Results for observation: 5264
# Results for observation: 5265
# Results for observation: 5266
# Results for observation: 5267
# Results for observation: 5268
# Results for observation: 5269
# Results for observation: 5270
# Results for observation: 5271
# Results for observation: 5272
# Results for observation: 5273
# Results for observation: 5274
# Results for observation: 5275
# Results for observation: 5276
# Results for observation: 5277
# Results for observation: 5278
# Results for observation: 5279
# Results for observation: 5280
# Results for observation: 5281
# Results for observation: 5282
# Results for observation: 5283
# Results for observation: 5284
# Results for observation: 5285
# Results for observation: 5286
# Results for observation: 5287
# Results for observation: 5288
# Results for observation: 5289
# Results for observation: 5290
# Results for observation: 5291
# Results for observation: 5292
# Results for observation: 5293
# Results for observation: 5294
# Results for observation: 5295
# Results for observation: 5296
# Results for observation: 5297
# Results for observation: 5298
# Results for observation: 5299
# Results for observation: 5300
# Results for observation: 5301
# Results for observation: 5302
# Results for observation: 5303
# Results for observation: 5304
# Results for observation: 5305
# Results for observation: 5306
# Results for observation: 5307
# Results for observation: 5308
# Results for observation: 5309
# Results for observation: 5310
# Results for observation: 5311
# Results for observation: 5312
# Results for observation: 5313
# Results for observation: 5314
# Results for observation: 5315
# Results for observation: 5316
# Results for observation: 5317
# Results for observation: 5318
# Results for observation: 5319
# Results for observation: 5320
# Results for observation: 5321
# Results for observation: 5322
# Results for observation: 5323
# Results for observation: 5324
# Results for observation: 5325
# Results for observation: 5326
# Results for observation: 5327
# Results for observation: 5328
# Results for observation: 5329
# Results for observation: 5330
# Results for observation: 5331
# Results for observation: 5332
# Results for observation: 5333
# Results for observation: 5334
# Results for observation: 5335
# Results for observation: 5336
# Results for observation: 5337
# Results for observation: 5338
# Results for observation: 5339
# Results for observation: 5340
# Results for observation: 5341
# Results for observation: 5342
# Results for observation: 5343
# Results for observation: 5344
# Results for observation: 5345
# Results for observation: 5346
# Results for observation: 5347
# Results for observation: 5348
# Results for observation: 5349
# Results for observation: 5350
# Results for observation: 5351
# Results for observation: 5352
# Results for observation: 5353
# Results for observation: 5354
# Results for observation: 5355
# Results for observation: 5356
# Results for observation: 5357
# Results for observation: 5358
# Results for observation: 5359
# Results for observation: 5360
# Results for observation: 5361
# Results for observation: 5362
# Results for observation: 5363
# Results for observation: 5364
# Results for observation: 5365
# Results for observation: 5366
# Results for observation: 5367
# Results for observation: 5368
# Results for observation: 5369
# Results for observation: 5370
# Results for observation: 5371
# Results for observation: 5372
# Results for observation: 5373
# Results for observation: 5374
# Results for observation: 5375
# Results for observation: 5376
# Results for observation: 5377
# Results for observation: 5378
# Results for observation: 5379
# Results for observation: 5380
# Results for observation: 5381
# Results for observation: 5382
# Results for observation: 5383
# Results for observation: 5384
# Results for observation: 5385
# Results for observation: 5386
# Results for observation: 5387
# Results for observation: 5388
# Results for observation: 5389
# Results for observation: 5390
# Results for observation: 5391
# Results for observation: 5392
# Results for observation: 5393
# Results for observation: 5394
# Results for observation: 5395
# Results for observation: 5396
# Results for observation: 5397
# Results for observation: 5398
# Results for observation: 5399
# Results for observation: 5400
# Results for observation: 5401
# Results for observation: 5402
# Results for observation: 5403
# Results for observation: 5404
# Results for observation: 5405
# Results for observation: 5406
# Results for observation: 5407
# Results for observation: 5408
# Results for observation: 5409
# Results for observation: 5410
# Results for observation: 5411
# Results for observation: 5412
# Results for observation: 5413
# Results for observation: 5414
# Results for observation: 5415
# Results for observation: 5416
# Results for observation: 5417
# Results for observation: 5418
# Results for observation: 5419
# Results for observation: 5420
# Results for observation: 5421
# Results for observation: 5422
# Results for observation: 5423
# Results for observation: 5424
# Results for observation: 5425
# Results for observation: 5426
# Results for observation: 5427
# Results for observation: 5428
# Results for observation: 5429
# Results for observation: 5430
# Results for observation: 5431
# Results for observation: 5432
# Results for observation: 5433
# Results for observation: 5434
# Results for observation: 5435
# Results for observation: 5436
# Results for observation: 5437
# Results for observation: 5438
# Results for observation: 5439
# Results for observation: 5440
# Results for observation: 5441
# Results for observation: 5442
# Results for observation: 5443
# Results for observation: 5444
# Results for observation: 5445
# Results for observation: 5446
# Results for observation: 5447
# Results for observation: 5448
# Results for observation: 5449
# Results for observation: 5450
# Results for observation: 5451
# Results for observation: 5452
# Results for observation: 5453
# Results for observation: 5454
# Results for observation: 5455
# Results for observation: 5456
# Results for observation: 5457
# Results for observation: 5458
# Results for observation: 5459
# Results for observation: 5460
# Results for observation: 5461
# Results for observation: 5462
# Results for observation: 5463
# Results for observation: 5464
# Results for observation: 5465
# Results for observation: 5466
# Results for observation: 5467
# Results for observation: 5468
# Results for observation: 5469
# Results for observation: 5470
# Results for observation: 5471
# Results for observation: 5472
# Results for observation: 5473
# Results for observation: 5474
# Results for observation: 5475
# Results for observation: 5476
# Results for observation: 5477
# Results for observation: 5478
# Results for observation: 5479
# Results for observation: 5480
# Results for observation: 5481
# Results for observation: 5482
# Results for observation: 5483
# Results for observation: 5484
# Results for observation: 5485
# Results for observation: 5486
# Results for observation: 5487
# Results for observation: 5488
# Results for observation: 5489
# Results for observation: 5490
# Results for observation: 5491
# Results for observation: 5492
# Results for observation: 5493
# Results for observation: 5494
# Results for observation: 5495
# Results for observation: 5496
# Results for observation: 5497
# Results for observation: 5498
# Results for observation: 5499
# Results for observation: 5500
# Results for observation: 5501
# Results for observation: 5502
# Results for observation: 5503
# Results for observation: 5504
# Results for observation: 5505
# Results for observation: 5506
# Results for observation: 5507
# Results for observation: 5508
# Results for observation: 5509
# Results for observation: 5510
# Results for observation: 5511
# Results for observation: 5512
# Results for observation: 5513
# Results for observation: 5514
# Results for observation: 5515
# Results for observation: 5516
# Results for observation: 5517
# Results for observation: 5518
# Results for observation: 5519
# Results for observation: 5520
# Results for observation: 5521
# Results for observation: 5522
# Results for observation: 5523
# Results for observation: 5524
# Results for observation: 5525
# Results for observation: 5526
# Results for observation: 5527
# Results for observation: 5528
# Results for observation: 5529
# Results for observation: 5530
# Results for observation: 5531
# Results for observation: 5532
# Results for observation: 5533
# Results for observation: 5534
# Results for observation: 5535
# Results for observation: 5536
# Results for observation: 5537
# Results for observation: 5538
# Results for observation: 5539
# Results for observation: 5540
# Results for observation: 5541
# Results for observation: 5542
# Results for observation: 5543
# Results for observation: 5544
# Results for observation: 5545
# Results for observation: 5546
# Results for observation: 5547
# Results for observation: 5548
# Results for observation: 5549
# Results for observation: 5550
# Results for observation: 5551
# Results for observation: 5552
# Results for observation: 5553
# Results for observation: 5554
# Results for observation: 5555
# Results for observation: 5556
# Results for observation: 5557
# Results for observation: 5558
# Results for observation: 5559
# Results for observation: 5560
# Results for observation: 5561
# Results for observation: 5562
# Results for observation: 5563
# Results for observation: 5564
# Results for observation: 5565
# Results for observation: 5566
# Results for observation: 5567
# Results for observation: 5568
# Results for observation: 5569
# Results for observation: 5570
# Results for observation: 5571
# Results for observation: 5572
# Results for observation: 5573
# Results for observation: 5574
# Results for observation: 5575
# Results for observation: 5576
# Results for observation: 5577
# Results for observation: 5578
# Results for observation: 5579
# Results for observation: 5580
# Results for observation: 5581
# Results for observation: 5582
# Results for observation: 5583
# Results for observation: 5584
# Results for observation: 5585
# Results for observation: 5586
# Results for observation: 5587
# Results for observation: 5588
# Results for observation: 5589
# Results for observation: 5590
# Results for observation: 5591
# Results for observation: 5592
# Results for observation: 5593
# Results for observation: 5594
# Results for observation: 5595
# Results for observation: 5596
# Results for observation: 5597
# Results for observation: 5598
# Results for observation: 5599
# Results for observation: 5600
# Results for observation: 5601
# Results for observation: 5602
# Results for observation: 5603
# Results for observation: 5604
# Results for observation: 5605
# Results for observation: 5606
# Results for observation: 5607
# Results for observation: 5608
# Results for observation: 5609
# Results for observation: 5610
# Results for observation: 5611
# Results for observation: 5612
# Results for observation: 5613
# Results for observation: 5614
# Results for observation: 5615
# Results for observation: 5616
# Results for observation: 5617
# Results for observation: 5618
# Results for observation: 5619
# Results for observation: 5620
# Results for observation: 5621
# Results for observation: 5622
# Results for observation: 5623
# Results for observation: 5624
# Results for observation: 5625
# Results for observation: 5626
# Results for observation: 5627
# Results for observation: 5628
# Results for observation: 5629
# Results for observation: 5630
# Results for observation: 5631
# Results for observation: 5632
# Results for observation: 5633
# Results for observation: 5634
# Results for observation: 5635
# Results for observation: 5636
# Results for observation: 5637
# Results for observation: 5638
# Results for observation: 5639
# Results for observation: 5640
# Results for observation: 5641
# Results for observation: 5642
# Results for observation: 5643
# Results for observation: 5644
# Results for observation: 5645
# Results for observation: 5646
# Results for observation: 5647
# Results for observation: 5648
# Results for observation: 5649
# Results for observation: 5650
# Results for observation: 5651
# Results for observation: 5652
# Results for observation: 5653
# Results for observation: 5654
# Results for observation: 5655
# Results for observation: 5656
# Results for observation: 5657
# Results for observation: 5658
# Results for observation: 5659
# Results for observation: 5660
# Results for observation: 5661
# Results for observation: 5662
# Results for observation: 5663
# Results for observation: 5664
# Results for observation: 5665
# Results for observation: 5666
# Results for observation: 5667
# Results for observation: 5668
# Results for observation: 5669
# Results for observation: 5670
# Results for observation: 5671
# Results for observation: 5672
# Results for observation: 5673
# Results for observation: 5674
# Results for observation: 5675
# Results for observation: 5676
# Results for observation: 5677
# Results for observation: 5678
# Results for observation: 5679
# Results for observation: 5680
# Results for observation: 5681
# Results for observation: 5682
# Results for observation: 5683
# Results for observation: 5684
# Results for observation: 5685
# Results for observation: 5686
# Results for observation: 5687
# Results for observation: 5688
# Results for observation: 5689
# Results for observation: 5690
# Results for observation: 5691
# Results for observation: 5692
# Results for observation: 5693
# Results for observation: 5694
# Results for observation: 5695
# Results for observation: 5696
# Results for observation: 5697
# Results for observation: 5698
# Results for observation: 5699
# Results for observation: 5700
# Results for observation: 5701
# Results for observation: 5702
# Results for observation: 5703
# Results for observation: 5704
# Results for observation: 5705
# Results for observation: 5706
# Results for observation: 5707
# Results for observation: 5708
# Results for observation: 5709
# Results for observation: 5710
# Results for observation: 5711
# Results for observation: 5712
# Results for observation: 5713
# Results for observation: 5714
# Results for observation: 5715
# Results for observation: 5716
# Results for observation: 5717
# Results for observation: 5718
# Results for observation: 5719
# Results for observation: 5720
# Results for observation: 5721
# Results for observation: 5722
# Results for observation: 5723
# Results for observation: 5724
# Results for observation: 5725
# Results for observation: 5726
# Results for observation: 5727
# Results for observation: 5728
# Results for observation: 5729
# Results for observation: 5730
# Results for observation: 5731
# Results for observation: 5732
# Results for observation: 5733
# Results for observation: 5734
# Results for observation: 5735
# Results for observation: 5736
# Results for observation: 5737
# Results for observation: 5738
# Results for observation: 5739
# Results for observation: 5740
# Results for observation: 5741
# Results for observation: 5742
# Results for observation: 5743
# Results for observation: 5744
# Results for observation: 5745
# Results for observation: 5746
# Results for observation: 5747
# Results for observation: 5748
# Results for observation: 5749
# Results for observation: 5750
# Results for observation: 5751
# Results for observation: 5752
# Results for observation: 5753
# Results for observation: 5754
# Results for observation: 5755
# Results for observation: 5756
# Results for observation: 5757
# Results for observation: 5758
# Results for observation: 5759
# Results for observation: 5760
# Results for observation: 5761
# Results for observation: 5762
# Results for observation: 5763
# Results for observation: 5764
# Results for observation: 5765
# Results for observation: 5766
# Results for observation: 5767
# Results for observation: 5768
# Results for observation: 5769
# Results for observation: 5770
# Results for observation: 5771
# Results for observation: 5772
# Results for observation: 5773
# Results for observation: 5774
# Results for observation: 5775
# Results for observation: 5776
# Results for observation: 5777
# Results for observation: 5778
# Results for observation: 5779
# Results for observation: 5780
# Results for observation: 5781
# Results for observation: 5782
# Results for observation: 5783
# Results for observation: 5784
# Results for observation: 5785
# Results for observation: 5786
# Results for observation: 5787
# Results for observation: 5788
# Results for observation: 5789
# Results for observation: 5790
# Results for observation: 5791
# Results for observation: 5792
# Results for observation: 5793
# Results for observation: 5794
# Results for observation: 5795
# Results for observation: 5796
# Results for observation: 5797
# Results for observation: 5798
# Results for observation: 5799
# Results for observation: 5800
# Results for observation: 5801
# Results for observation: 5802
# Results for observation: 5803
# Results for observation: 5804
# Results for observation: 5805
# Results for observation: 5806
# Results for observation: 5807
# Results for observation: 5808
# Results for observation: 5809
# Results for observation: 5810
# Results for observation: 5811
# Results for observation: 5812
# Results for observation: 5813
# Results for observation: 5814
# Results for observation: 5815
# Results for observation: 5816
# Results for observation: 5817
# Results for observation: 5818
# Results for observation: 5819
# Results for observation: 5820
# Results for observation: 5821
# Results for observation: 5822
# Results for observation: 5823
# Results for observation: 5824
# Results for observation: 5825
# Results for observation: 5826
# Results for observation: 5827
# Results for observation: 5828
# Results for observation: 5829
# Results for observation: 5830
# Results for observation: 5831
# Results for observation: 5832
# Results for observation: 5833
# Results for observation: 5834
# Results for observation: 5835
# Results for observation: 5836
# Results for observation: 5837
# Results for observation: 5838
# Results for observation: 5839
# Results for observation: 5840
# Results for observation: 5841
# Results for observation: 5842
# Results for observation: 5843
# Results for observation: 5844
# Results for observation: 5845
# Results for observation: 5846
# Results for observation: 5847
# Results for observation: 5848
# Results for observation: 5849
# Results for observation: 5850
# Results for observation: 5851
# Results for observation: 5852
# Results for observation: 5853
# Results for observation: 5854
# Results for observation: 5855
# Results for observation: 5856
# Results for observation: 5857
# Results for observation: 5858
# Results for observation: 5859
# Results for observation: 5860
# Results for observation: 5861
# Results for observation: 5862
# Results for observation: 5863
# Results for observation: 5864
# Results for observation: 5865
# Results for observation: 5866
# Results for observation: 5867
# Results for observation: 5868
# Results for observation: 5869
# Results for observation: 5870
# Results for observation: 5871
# Results for observation: 5872
# Results for observation: 5873
# Results for observation: 5874
# Results for observation: 5875
# Results for observation: 5876
# Results for observation: 5877
# Results for observation: 5878
# Results for observation: 5879
# Results for observation: 5880
# Results for observation: 5881
# Results for observation: 5882
# Results for observation: 5883
# Results for observation: 5884
# Results for observation: 5885
# Results for observation: 5886
# Results for observation: 5887
# Results for observation: 5888
# Results for observation: 5889
# Results for observation: 5890
# Results for observation: 5891
# Results for observation: 5892
# Results for observation: 5893
# Results for observation: 5894
# Results for observation: 5895
# Results for observation: 5896
# Results for observation: 5897
# Results for observation: 5898
# Results for observation: 5899
# Results for observation: 5900
# Results for observation: 5901
# Results for observation: 5902
# Results for observation: 5903
# Results for observation: 5904
# Results for observation: 5905
# Results for observation: 5906
# Results for observation: 5907
# Results for observation: 5908
# Results for observation: 5909
# Results for observation: 5910
# Results for observation: 5911
# Results for observation: 5912
# Results for observation: 5913
# Results for observation: 5914
# Results for observation: 5915
# Results for observation: 5916
# Results for observation: 5917
# Results for observation: 5918
# Results for observation: 5919
# Results for observation: 5920
# Results for observation: 5921
# Results for observation: 5922
# Results for observation: 5923
# Results for observation: 5924
# Results for observation: 5925
# Results for observation: 5926
# Results for observation: 5927
# Results for observation: 5928
# Results for observation: 5929
# Results for observation: 5930
# Results for observation: 5931
# Results for observation: 5932
# Results for observation: 5933
# Results for observation: 5934
# Results for observation: 5935
# Results for observation: 5936
# Results for observation: 5937
# Results for observation: 5938
# Results for observation: 5939
# Results for observation: 5940
# Results for observation: 5941
# Results for observation: 5942
# Results for observation: 5943
# Results for observation: 5944
# Results for observation: 5945
# Results for observation: 5946
# Results for observation: 5947
# Results for observation: 5948
# Results for observation: 5949
# Results for observation: 5950
# Results for observation: 5951
# Results for observation: 5952
# Results for observation: 5953
# Results for observation: 5954
# Results for observation: 5955
# Results for observation: 5956
# Results for observation: 5957
# Results for observation: 5958
# Results for observation: 5959
# Results for observation: 5960
# Results for observation: 5961
# Results for observation: 5962
# Results for observation: 5963
# Results for observation: 5964
# Results for observation: 5965
# Results for observation: 5966
# Results for observation: 5967
# Results for observation: 5968
# Results for observation: 5969
# Results for observation: 5970
# Results for observation: 5971
# Results for observation: 5972
# Results for observation: 5973
# Results for observation: 5974
# Results for observation: 5975
# Results for observation: 5976
# Results for observation: 5977
# Results for observation: 5978
# Results for observation: 5979
# Results for observation: 5980
# Results for observation: 5981
# Results for observation: 5982
# Results for observation: 5983
# Results for observation: 5984
# Results for observation: 5985
# Results for observation: 5986
# Results for observation: 5987
# Results for observation: 5988
# Results for observation: 5989
# Results for observation: 5990
# Results for observation: 5991
# Results for observation: 5992
# Results for observation: 5993
# Results for observation: 5994
# Results for observation: 5995
# Results for observation: 5996
# Results for observation: 5997
# Results for observation: 5998
# Results for observation: 5999
# Results for observation: 6000
# Results for observation: 6001
# Results for observation: 6002
# Results for observation: 6003
# Results for observation: 6004
# Results for observation: 6005
# Results for observation: 6006
# Results for observation: 6007
# Results for observation: 6008
# Results for observation: 6009
# Results for observation: 6010
# Results for observation: 6011
# Results for observation: 6012
# Results for observation: 6013
# Results for observation: 6014
# Results for observation: 6015
# Results for observation: 6016
# Results for observation: 6017
# Results for observation: 6018
# Results for observation: 6019
# Results for observation: 6020
# Results for observation: 6021
# Results for observation: 6022
# Results for observation: 6023
# Results for observation: 6024
# Results for observation: 6025
# Results for observation: 6026
# Results for observation: 6027
# Results for observation: 6028
# Results for observation: 6029
# Results for observation: 6030
# Results for observation: 6031
# Results for observation: 6032
# Results for observation: 6033
# Results for observation: 6034
# Results for observation: 6035
# Results for observation: 6036
# Results for observation: 6037
# Results for observation: 6038
# Results for observation: 6039
# Results for observation: 6040
# Results for observation: 6041
# Results for observation: 6042
# Results for observation: 6043
# Results for observation: 6044
# Results for observation: 6045
# Results for observation: 6046
# Results for observation: 6047
# Results for observation: 6048
# Results for observation: 6049
# Results for observation: 6050
# Results for observation: 6051
# Results for observation: 6052
# Results for observation: 6053
# Results for observation: 6054
# Results for observation: 6055
# Results for observation: 6056
# Results for observation: 6057
# Results for observation: 6058
# Results for observation: 6059
# Results for observation: 6060
# Results for observation: 6061
# Results for observation: 6062
# Results for observation: 6063
# Results for observation: 6064
# Results for observation: 6065
# Results for observation: 6066
# Results for observation: 6067
# Results for observation: 6068
# Results for observation: 6069
# Results for observation: 6070
# Results for observation: 6071
# Results for observation: 6072
# Results for observation: 6073
# Results for observation: 6074
# Results for observation: 6075
# Results for observation: 6076
# Results for observation: 6077
# Results for observation: 6078
# Results for observation: 6079
# Results for observation: 6080
# Results for observation: 6081
# Results for observation: 6082
# Results for observation: 6083
# Results for observation: 6084
# Results for observation: 6085
# Results for observation: 6086
# Results for observation: 6087
# Results for observation: 6088
# Results for observation: 6089
# Results for observation: 6090
# Results for observation: 6091
# Results for observation: 6092
# Results for observation: 6093
# Results for observation: 6094
# Results for observation: 6095
# Results for observation: 6096
# Results for observation: 6097
# Results for observation: 6098
# Results for observation: 6099
# Results for observation: 6100
# Results for observation: 6101
# Results for observation: 6102
# Results for observation: 6103
# Results for observation: 6104
# Results for observation: 6105
# Results for observation: 6106
# Results for observation: 6107
# Results for observation: 6108
# Results for observation: 6109
# Results for observation: 6110
# Results for observation: 6111
# Results for observation: 6112
# Results for observation: 6113
# Results for observation: 6114
# Results for observation: 6115
# Results for observation: 6116
# Results for observation: 6117
# Results for observation: 6118
# Results for observation: 6119
# Results for observation: 6120
# Results for observation: 6121
# Results for observation: 6122
# Results for observation: 6123
# Results for observation: 6124
# Results for observation: 6125
# Results for observation: 6126
# Results for observation: 6127
# Results for observation: 6128
# Results for observation: 6129
# Results for observation: 6130
# Results for observation: 6131
# Results for observation: 6132
# Results for observation: 6133
# Results for observation: 6134
# Results for observation: 6135
# Results for observation: 6136
# Results for observation: 6137
# Results for observation: 6138
# Results for observation: 6139
# Results for observation: 6140
# Results for observation: 6141
# Results for observation: 6142
# Results for observation: 6143
# Results for observation: 6144
# Results for observation: 6145
# Results for observation: 6146
# Results for observation: 6147
# Results for observation: 6148
# Results for observation: 6149
# Results for observation: 6150
# Results for observation: 6151
# Results for observation: 6152
# Results for observation: 6153
# Results for observation: 6154
# Results for observation: 6155
# Results for observation: 6156
# Results for observation: 6157
# Results for observation: 6158
# Results for observation: 6159
# Results for observation: 6160
# Results for observation: 6161
# Results for observation: 6162
# Results for observation: 6163
# Results for observation: 6164
# Results for observation: 6165
# Results for observation: 6166
# Results for observation: 6167
# Results for observation: 6168
# Results for observation: 6169
# Results for observation: 6170
# Results for observation: 6171
# Results for observation: 6172
# Results for observation: 6173
# Results for observation: 6174
# Results for observation: 6175
# Results for observation: 6176
# Results for observation: 6177
# Results for observation: 6178
# Results for observation: 6179
# Results for observation: 6180
# Results for observation: 6181
# Results for observation: 6182
# Results for observation: 6183
# Results for observation: 6184
# Results for observation: 6185
# Results for observation: 6186
# Results for observation: 6187
# Results for observation: 6188
# Results for observation: 6189
# Results for observation: 6190
# Results for observation: 6191
# Results for observation: 6192
# Results for observation: 6193
# Results for observation: 6194
# Results for observation: 6195
# Results for observation: 6196
# Results for observation: 6197
# Results for observation: 6198
# Results for observation: 6199
# Results for observation: 6200
# Results for observation: 6201
# Results for observation: 6202
# Results for observation: 6203
# Results for observation: 6204
# Results for observation: 6205
# Results for observation: 6206
# Results for observation: 6207
# Results for observation: 6208
# Results for observation: 6209
# Results for observation: 6210
# Results for observation: 6211
# Results for observation: 6212
# Results for observation: 6213
# Results for observation: 6214
# Results for observation: 6215
# Results for observation: 6216
# Results for observation: 6217
# Results for observation: 6218
# Results for observation: 6219
# Results for observation: 6220
# Results for observation: 6221
# Results for observation: 6222
# Results for observation: 6223
# Results for observation: 6224
# Results for observation: 6225
# Results for observation: 6226
# Results for observation: 6227
# Results for observation: 6228
# Results for observation: 6229
# Results for observation: 6230
# Results for observation: 6231
# Results for observation: 6232
# Results for observation: 6233
# Results for observation: 6234
# Results for observation: 6235
# Results for observation: 6236
# Results for observation: 6237
# Results for observation: 6238
# Results for observation: 6239
# Results for observation: 6240
# Results for observation: 6241
# Results for observation: 6242
# Results for observation: 6243
# Results for observation: 6244
# Results for observation: 6245
# Results for observation: 6246
# Results for observation: 6247
# Results for observation: 6248
# Results for observation: 6249
# Results for observation: 6250
# Results for observation: 6251
# Results for observation: 6252
# Results for observation: 6253
# Results for observation: 6254
# Results for observation: 6255
# Results for observation: 6256
# Results for observation: 6257
# Results for observation: 6258
# Results for observation: 6259
# Results for observation: 6260
# Results for observation: 6261
# Results for observation: 6262
# Results for observation: 6263
# Results for observation: 6264
# Results for observation: 6265
# Results for observation: 6266
# Results for observation: 6267
# Results for observation: 6268
# Results for observation: 6269
# Results for observation: 6270
# Results for observation: 6271
# Results for observation: 6272
# Results for observation: 6273
# Results for observation: 6274
# Results for observation: 6275
# Results for observation: 6276
# Results for observation: 6277
# Results for observation: 6278
# Results for observation: 6279
# Results for observation: 6280
# Results for observation: 6281
# Results for observation: 6282
# Results for observation: 6283
# Results for observation: 6284
# Results for observation: 6285
# Results for observation: 6286
# Results for observation: 6287
# Results for observation: 6288
# Results for observation: 6289
# Results for observation: 6290
# Results for observation: 6291
# Results for observation: 6292
# Results for observation: 6293
# Results for observation: 6294
# Results for observation: 6295
# Results for observation: 6296
# Results for observation: 6297
# Results for observation: 6298
# Results for observation: 6299
# Results for observation: 6300
# Results for observation: 6301
# Results for observation: 6302
# Results for observation: 6303
# Results for observation: 6304
# Results for observation: 6305
# Results for observation: 6306
# Results for observation: 6307
# Results for observation: 6308
# Results for observation: 6309
# Results for observation: 6310
# Results for observation: 6311
# Results for observation: 6312
# Results for observation: 6313
# Results for observation: 6314
# Results for observation: 6315
# Results for observation: 6316
# Results for observation: 6317
# Results for observation: 6318
# Results for observation: 6319
# Results for observation: 6320
# Results for observation: 6321
# Results for observation: 6322
# Results for observation: 6323
# Results for observation: 6324
# Results for observation: 6325
# Results for observation: 6326
# Results for observation: 6327
# Results for observation: 6328
# Results for observation: 6329
# Results for observation: 6330
# Results for observation: 6331
# Results for observation: 6332
# Results for observation: 6333
# Results for observation: 6334
# Results for observation: 6335
# Results for observation: 6336
# Results for observation: 6337
# Results for observation: 6338
# Results for observation: 6339
# Results for observation: 6340
# Results for observation: 6341
# Results for observation: 6342
# Results for observation: 6343
# Results for observation: 6344
# Results for observation: 6345
# Results for observation: 6346
# Results for observation: 6347
# Results for observation: 6348
# Results for observation: 6349
# Results for observation: 6350
# Results for observation: 6351
# Results for observation: 6352
# Results for observation: 6353
# Results for observation: 6354
# Results for observation: 6355
# Results for observation: 6356
# Results for observation: 6357
# Results for observation: 6358
# Results for observation: 6359
# Results for observation: 6360
# Results for observation: 6361
# Results for observation: 6362
# Results for observation: 6363
# Results for observation: 6364
# Results for observation: 6365
# Results for observation: 6366
# Results for observation: 6367
# Results for observation: 6368
# Results for observation: 6369
# Results for observation: 6370
# Results for observation: 6371
# Results for observation: 6372
# Results for observation: 6373
# Results for observation: 6374
# Results for observation: 6375
# Results for observation: 6376
# Results for observation: 6377
# Results for observation: 6378
# Results for observation: 6379
# Results for observation: 6380
# Results for observation: 6381
# Results for observation: 6382
# Results for observation: 6383
# Results for observation: 6384
# Results for observation: 6385
# Results for observation: 6386
# Results for observation: 6387
# Results for observation: 6388
# Results for observation: 6389
# Results for observation: 6390
# Results for observation: 6391
# Results for observation: 6392
# Results for observation: 6393
# Results for observation: 6394
# Results for observation: 6395
# Results for observation: 6396
# Results for observation: 6397
# Results for observation: 6398
# Results for observation: 6399
# Results for observation: 6400
# Results for observation: 6401
# Results for observation: 6402
# Results for observation: 6403
# Results for observation: 6404
# Results for observation: 6405
# Results for observation: 6406
# Results for observation: 6407
# Results for observation: 6408
# Results for observation: 6409
# Results for observation: 6410
# Results for observation: 6411
# Results for observation: 6412
# Results for observation: 6413
# Results for observation: 6414
# Results for observation: 6415
# Results for observation: 6416
# Results for observation: 6417
# Results for observation: 6418
# Results for observation: 6419
# Results for observation: 6420
# Results for observation: 6421
# Results for observation: 6422
# Results for observation: 6423
# Results for observation: 6424
# Results for observation: 6425
# Results for observation: 6426
# Results for observation: 6427
# Results for observation: 6428
# Results for observation: 6429
# Results for observation: 6430
# Results for observation: 6431
# Results for observation: 6432
# Results for observation: 6433
# Results for observation: 6434
# Results for observation: 6435
# Results for observation: 6436
# Results for observation: 6437
# Results for observation: 6438
# Results for observation: 6439
# Results for observation: 6440
# Results for observation: 6441
# Results for observation: 6442
# Results for observation: 6443
# Results for observation: 6444
# Results for observation: 6445
# Results for observation: 6446
# Results for observation: 6447
# Results for observation: 6448
# Results for observation: 6449
# Results for observation: 6450
# Results for observation: 6451
# Results for observation: 6452
# Results for observation: 6453
# Results for observation: 6454
# Results for observation: 6455
# Results for observation: 6456
# Results for observation: 6457
# Results for observation: 6458
# Results for observation: 6459
# Results for observation: 6460
# Results for observation: 6461
# Results for observation: 6462
# Results for observation: 6463
# Results for observation: 6464
# Results for observation: 6465
# Results for observation: 6466
# Results for observation: 6467
# Results for observation: 6468
# Results for observation: 6469
# Results for observation: 6470
# Results for observation: 6471
# Results for observation: 6472
# Results for observation: 6473
# Results for observation: 6474
# Results for observation: 6475
# Results for observation: 6476
# Results for observation: 6477
# Results for observation: 6478
# Results for observation: 6479
# Results for observation: 6480
# Results for observation: 6481
# Results for observation: 6482
# Results for observation: 6483
# Results for observation: 6484
# Results for observation: 6485
# Results for observation: 6486
# Results for observation: 6487
# Results for observation: 6488
# Results for observation: 6489
# Results for observation: 6490
# Results for observation: 6491
# Results for observation: 6492
# Results for observation: 6493
# Results for observation: 6494
# Results for observation: 6495
# Results for observation: 6496
# Results for observation: 6497
# Results for observation: 6498
# Results for observation: 6499
# Results for observation: 6500
# Results for observation: 6501
# Results for observation: 6502
# Results for observation: 6503
# Results for observation: 6504
# Results for observation: 6505
# Results for observation: 6506
# Results for observation: 6507
# Results for observation: 6508
# Results for observation: 6509
# Results for observation: 6510
# Results for observation: 6511
# Results for observation: 6512
# Results for observation: 6513
# Results for observation: 6514
# Results for observation: 6515
# Results for observation: 6516
# Results for observation: 6517
# Results for observation: 6518
# Results for observation: 6519
# Results for observation: 6520
# Results for observation: 6521
# Results for observation: 6522
# Results for observation: 6523
# Results for observation: 6524
# Results for observation: 6525
# Results for observation: 6526
# Results for observation: 6527
# Results for observation: 6528
# Results for observation: 6529
# Results for observation: 6530
# Results for observation: 6531
# Results for observation: 6532
# Results for observation: 6533
# Results for observation: 6534
# Results for observation: 6535
# Results for observation: 6536
# Results for observation: 6537
# Results for observation: 6538
# Results for observation: 6539
# Results for observation: 6540
# Results for observation: 6541
# Results for observation: 6542
# Results for observation: 6543
# Results for observation: 6544
# Results for observation: 6545
# Results for observation: 6546
# Results for observation: 6547
# Results for observation: 6548
# Results for observation: 6549
# Results for observation: 6550
# Results for observation: 6551
# Results for observation: 6552
# Results for observation: 6553
# Results for observation: 6554
# Results for observation: 6555
# Results for observation: 6556
# Results for observation: 6557
# Results for observation: 6558
# Results for observation: 6559
# Results for observation: 6560
# Results for observation: 6561
# Results for observation: 6562
# Results for observation: 6563
# Results for observation: 6564
# Results for observation: 6565
# Results for observation: 6566
# Results for observation: 6567
# Results for observation: 6568
# ...
# Results for observation: 6942
# Results for observation: 6943
# Results for observation: 6944
# Results for observation: 6945
# Results for observation: 6946
# Results for observation: 6947
# Results for observation: 6948
# Results for observation: 6949
# Results for observation: 6950
# Results for observation: 6951
# Results for observation: 6952
# Results for observation: 6953
# Results for observation: 6954
# Results for observation: 6955
# Results for observation: 6956
# Results for observation: 6957
# Results for observation: 6958
# Results for observation: 6959
# Results for observation: 6960
# Results for observation: 6961
# Results for observation: 6962
# Results for observation: 6963
# Results for observation: 6964
# Results for observation: 6965
# Results for observation: 6966
# Results for observation: 6967
# Results for observation: 6968
# Results for observation: 6969
# Results for observation: 6970
# Results for observation: 6971
# Results for observation: 6972
# Results for observation: 6973
# Results for observation: 6974
# Results for observation: 6975
# Results for observation: 6976
# Results for observation: 6977
# Results for observation: 6978
# Results for observation: 6979
# Results for observation: 6980
# Results for observation: 6981
# Results for observation: 6982
# Results for observation: 6983
# Results for observation: 6984
# Results for observation: 6985
# Results for observation: 6986
# Results for observation: 6987
# Results for observation: 6988
# Results for observation: 6989
# Results for observation: 6990
# Results for observation: 6991
# Results for observation: 6992
# Results for observation: 6993
# Results for observation: 6994
# Results for observation: 6995
# Results for observation: 6996
# Results for observation: 6997
# Results for observation: 6998
# Results for observation: 6999
# Results for observation: 7000
# Results for observation: 7001
# Results for observation: 7002
# Results for observation: 7003
# Results for observation: 7004
# Results for observation: 7005
# Results for observation: 7006
# Results for observation: 7007
# Results for observation: 7008
# Results for observation: 7009
# Results for observation: 7010
# Results for observation: 7011
# Results for observation: 7012
# Results for observation: 7013
# Results for observation: 7014
# Results for observation: 7015
# Results for observation: 7016
# Results for observation: 7017
# Results for observation: 7018
# Results for observation: 7019
# Results for observation: 7020
# Results for observation: 7021
# Results for observation: 7022
# Results for observation: 7023
# Results for observation: 7024
# Results for observation: 7025
# Results for observation: 7026
# Results for observation: 7027
# Results for observation: 7028
# Results for observation: 7029
# Results for observation: 7030
# Results for observation: 7031
# Results for observation: 7032
# Results for observation: 7033
# Results for observation: 7034
# Results for observation: 7035
# Results for observation: 7036
# Results for observation: 7037
# Results for observation: 7038
# Results for observation: 7039
# Results for observation: 7040
# Results for observation: 7041
# Results for observation: 7042
# Results for observation: 7043
# Results for observation: 7044
# Results for observation: 7045
# Results for observation: 7046
# Results for observation: 7047
# Results for observation: 7048
# Results for observation: 7049
# Results for observation: 7050
# Results for observation: 7051
# Results for observation: 7052
# Results for observation: 7053
# Results for observation: 7054
# Results for observation: 7055
# Results for observation: 7056
# Results for observation: 7057
# Results for observation: 7058
# Results for observation: 7059
# Results for observation: 7060
# Results for observation: 7061
# Results for observation: 7062
# Results for observation: 7063
# Results for observation: 7064
# Results for observation: 7065
# Results for observation: 7066
# Results for observation: 7067
# Results for observation: 7068
# Results for observation: 7069
# Results for observation: 7070
# Results for observation: 7071
# Results for observation: 7072
# Results for observation: 7073
# Results for observation: 7074
# Results for observation: 7075
# Results for observation: 7076
# Results for observation: 7077
# Results for observation: 7078
# Results for observation: 7079
# Results for observation: 7080
# Results for observation: 7081
# Results for observation: 7082
# Results for observation: 7083
# Results for observation: 7084
# Results for observation: 7085
# Results for observation: 7086
# Results for observation: 7087
# Results for observation: 7088
# Results for observation: 7089
# Results for observation: 7090
# Results for observation: 7091
# Results for observation: 7092
# Results for observation: 7093
# Results for observation: 7094
# Results for observation: 7095
# Results for observation: 7096
# Results for observation: 7097
# Results for observation: 7098
# Results for observation: 7099
# Results for observation: 7100
# Results for observation: 7101
# Results for observation: 7102
# Results for observation: 7103
# Results for observation: 7104
# Results for observation: 7105
# Results for observation: 7106
# Results for observation: 7107
# Results for observation: 7108
# Results for observation: 7109
# Results for observation: 7110
# Results for observation: 7111
# Results for observation: 7112
# Results for observation: 7113
# Results for observation: 7114
# Results for observation: 7115
# Results for observation: 7116
# Results for observation: 7117
# Results for observation: 7118
# Results for observation: 7119
# Results for observation: 7120
# Results for observation: 7121
# Results for observation: 7122
# Results for observation: 7123
# Results for observation: 7124
# Results for observation: 7125
# Results for observation: 7126
# Results for observation: 7127
# Results for observation: 7128
# Results for observation: 7129
# Results for observation: 7130
# Results for observation: 7131
# Results for observation: 7132
# Results for observation: 7133
# Results for observation: 7134
# Results for observation: 7135
# Results for observation: 7136
# Results for observation: 7137
# Results for observation: 7138
# Results for observation: 7139
# Results for observation: 7140
# Results for observation: 7141
# Results for observation: 7142
# Results for observation: 7143
# Results for observation: 7144
# Results for observation: 7145
# Results for observation: 7146
# Results for observation: 7147
# Results for observation: 7148
# Results for observation: 7149
# Results for observation: 7150
# Results for observation: 7151
# Results for observation: 7152
# Results for observation: 7153
# Results for observation: 7154
# Results for observation: 7155
# Results for observation: 7156
# Results for observation: 7157
# Results for observation: 7158
# Results for observation: 7159
# Results for observation: 7160
# Results for observation: 7161
# Results for observation: 7162
# Results for observation: 7163
# Results for observation: 7164
# Results for observation: 7165
# Results for observation: 7166
# Results for observation: 7167
# Results for observation: 7168
# Results for observation: 7169
# Results for observation: 7170
# Results for observation: 7171
# Results for observation: 7172
# Results for observation: 7173
# Results for observation: 7174
# Results for observation: 7175
# Results for observation: 7176
# Results for observation: 7177
# Results for observation: 7178
# Results for observation: 7179
# Results for observation: 7180
# Results for observation: 7181
# Results for observation: 7182
# Results for observation: 7183
# Results for observation: 7184
# Results for observation: 7185
# Results for observation: 7186
# Results for observation: 7187
# Results for observation: 7188
# Results for observation: 7189
# Results for observation: 7190
# Results for observation: 7191
# Results for observation: 7192
# Results for observation: 7193
# Results for observation: 7194
# Results for observation: 7195
# Results for observation: 7196
# Results for observation: 7197
# Results for observation: 7198
# Results for observation: 7199
# Results for observation: 7200
# Results for observation: 7201
# Results for observation: 7202
# Results for observation: 7203
# Results for observation: 7204
# Results for observation: 7205
# Results for observation: 7206
# Results for observation: 7207
# Results for observation: 7208
# Results for observation: 7209
# Results for observation: 7210
# Results for observation: 7211
# Results for observation: 7212
# Results for observation: 7213
# Results for observation: 7214
# Results for observation: 7215
# Results for observation: 7216
# Results for observation: 7217
# Results for observation: 7218
# Results for observation: 7219
# Results for observation: 7220
# Results for observation: 7221
# Results for observation: 7222
# Results for observation: 7223
# Results for observation: 7224
# Results for observation: 7225
# Results for observation: 7226
# Results for observation: 7227
# Results for observation: 7228
# Results for observation: 7229
# Results for observation: 7230
# Results for observation: 7231
# Results for observation: 7232
# Results for observation: 7233
# Results for observation: 7234
# Results for observation: 7235
# Results for observation: 7236
# Results for observation: 7237
# Results for observation: 7238
# Results for observation: 7239
# Results for observation: 7240
# Results for observation: 7241
# Results for observation: 7242
# Results for observation: 7243
# Results for observation: 7244
# Results for observation: 7245
# Results for observation: 7246
# Results for observation: 7247
# Results for observation: 7248
# Results for observation: 7249
# Results for observation: 7250
# Results for observation: 7251
# Results for observation: 7252
# Results for observation: 7253
# Results for observation: 7254
# Results for observation: 7255
# Results for observation: 7256
# Results for observation: 7257
# Results for observation: 7258
# Results for observation: 7259
# Results for observation: 7260
# Results for observation: 7261
# Results for observation: 7262
# Results for observation: 7263
# Results for observation: 7264
# Results for observation: 7265
# Results for observation: 7266
# Results for observation: 7267
# Results for observation: 7268
# Results for observation: 7269
# Results for observation: 7270
# Results for observation: 7271
# Results for observation: 7272
# Results for observation: 7273
# Results for observation: 7274
# Results for observation: 7275
# Results for observation: 7276
# Results for observation: 7277
# Results for observation: 7278
# Results for observation: 7279
# Results for observation: 7280
# Results for observation: 7281
# Results for observation: 7282
# Results for observation: 7283
# Results for observation: 7284
# Results for observation: 7285
# Results for observation: 7286
# Results for observation: 7287
# Results for observation: 7288
# Results for observation: 7289
# Results for observation: 7290
# Results for observation: 7291
# Results for observation: 7292
# Results for observation: 7293
# Results for observation: 7294
# Results for observation: 7295
# Results for observation: 7296
# Results for observation: 7297
# Results for observation: 7298
# Results for observation: 7299
# Results for observation: 7300
# Results for observation: 7301
# Results for observation: 7302
# Results for observation: 7303
# Results for observation: 7304
# Results for observation: 7305
# Results for observation: 7306
# Results for observation: 7307
# Results for observation: 7308
# Results for observation: 7309
# Results for observation: 7310
# Results for observation: 7311
# Results for observation: 7312
# Results for observation: 7313
# Results for observation: 7314
# Results for observation: 7315
# Results for observation: 7316
# Results for observation: 7317
# Results for observation: 7318
# Results for observation: 7319
# Results for observation: 7320
# Results for observation: 7321
# Results for observation: 7322
# Results for observation: 7323
# Results for observation: 7324
# Results for observation: 7325
# Results for observation: 7326
# Results for observation: 7327
# Results for observation: 7328
# Results for observation: 7329
# Results for observation: 7330
# Results for observation: 7331
# Results for observation: 7332
# Results for observation: 7333
# Results for observation: 7334
# Results for observation: 7335
# Results for observation: 7336
# Results for observation: 7337
# Results for observation: 7338
# Results for observation: 7339
# Results for observation: 7340
# Results for observation: 7341
# Results for observation: 7342
# Results for observation: 7343
# Results for observation: 7344
# Results for observation: 7345
# Results for observation: 7346
# Results for observation: 7347
# Results for observation: 7348
# Results for observation: 7349
# Results for observation: 7350
# Results for observation: 7351
# Results for observation: 7352
# Results for observation: 7353
# Results for observation: 7354
# Results for observation: 7355
# Results for observation: 7356
# Results for observation: 7357
# Results for observation: 7358
# Results for observation: 7359
# Results for observation: 7360
# Results for observation: 7361
# Results for observation: 7362
# Results for observation: 7363
# Results for observation: 7364
# Results for observation: 7365
# Results for observation: 7366
# Results for observation: 7367
# Results for observation: 7368
# Results for observation: 7369
# Results for observation: 7370
# Results for observation: 7371
# Results for observation: 7372
# Results for observation: 7373
# Results for observation: 7374
# Results for observation: 7375
# Results for observation: 7376
# Results for observation: 7377
# Results for observation: 7378
# Results for observation: 7379
# Results for observation: 7380
# Results for observation: 7381
# Results for observation: 7382
# Results for observation: 7383
# Results for observation: 7384
# Results for observation: 7385
# Results for observation: 7386
# Results for observation: 7387
# Results for observation: 7388
# Results for observation: 7389
# Results for observation: 7390
# Results for observation: 7391
# Results for observation: 7392
# Results for observation: 7393
# Results for observation: 7394
# Results for observation: 7395
# Results for observation: 7396
# Results for observation: 7397
# Results for observation: 7398
# Results for observation: 7399
# Results for observation: 7400
# Results for observation: 7401
# Results for observation: 7402
# Results for observation: 7403
# Results for observation: 7404
# Results for observation: 7405
# Results for observation: 7406
# Results for observation: 7407
# Results for observation: 7408
# Results for observation: 7409
# Results for observation: 7410
# Results for observation: 7411
# Results for observation: 7412
# Results for observation: 7413
# Results for observation: 7414
# Results for observation: 7415
# Results for observation: 7416
# Results for observation: 7417
# Results for observation: 7418
# Results for observation: 7419
# Results for observation: 7420
# Results for observation: 7421
# Results for observation: 7422
# Results for observation: 7423
# Results for observation: 7424
# Results for observation: 7425
# Results for observation: 7426
# Results for observation: 7427
# Results for observation: 7428
# Results for observation: 7429
# Results for observation: 7430
# Results for observation: 7431
# Results for observation: 7432
# Results for observation: 7433
# Results for observation: 7434
# Results for observation: 7435
# Results for observation: 7436
# Results for observation: 7437
# Results for observation: 7438
# Results for observation: 7439
# Results for observation: 7440
# Results for observation: 7441
# Results for observation: 7442
# Results for observation: 7443
# Results for observation: 7444
# Results for observation: 7445
# Results for observation: 7446
# Results for observation: 7447
# Results for observation: 7448
# Results for observation: 7449
# Results for observation: 7450
# Results for observation: 7451
# Results for observation: 7452
# Results for observation: 7453
# Results for observation: 7454
# Results for observation: 7455
# Results for observation: 7456
# Results for observation: 7457
# Results for observation: 7458
# Results for observation: 7459
# Results for observation: 7460
# Results for observation: 7461
# Results for observation: 7462
# Results for observation: 7463
# Results for observation: 7464
# Results for observation: 7465
# Results for observation: 7466
# Results for observation: 7467
# Results for observation: 7468
# Results for observation: 7469
# Results for observation: 7470
# Results for observation: 7471
# Results for observation: 7472
# Results for observation: 7473
# Results for observation: 7474

# %%
part3 = pau_df

# %%
pau_df
# Out:
#       index                                               name  \
# 4983  13215                        Servicio La Parada SA de CV
# 4984  13218                             SERVIARAGON S.A DE C.V
# 4985  13221         Operadora de Gasolineras A.P. S.A. de C.V.
# 4986  13224  GASOLINERA CRISTOBAL COLON DE JUCHITAN S.A. DE...
# 4987  13227                          CARBURANTES, S.A. DE C.V.
# ...     ...                                                ...
# 7470  19760                    ESTACIONES MEXSON, S.A. DE C.V.
# 7471  19762                          EVERARDO LARA COVARRUBIAS
# 7472  19765                        SERVICIO COMONFORT SA DE CV
# 7473  19767                             ALFONSO COBIAN RAMIREZ
# 7474  19770          LA MERCANTIL DE GOMEZ FARIAS S.A. DE C.V.
#
#                    cre_id        Lng       Lat  place_id  gas_price gas type  \
# 4983  PL/4839/EXP/ES/2015  -98.05087  19.38949      7165      17.98  regular
# 4984  PL/4695/EXP/ES/2015  -98.61885  18.31530      7166      18.89  regular
# 4985  PL/4911/EXP/ES/2015  -99.69855  19.28886      7167      17.73  regular
# 4986  PL/3531/EXP/ES/2015  -95.02547  16.44553      7168      18.39  regular
# 4987  PL/4838/EXP/ES/2015  -99.51218  27.47712      7169      12.89  regular
# ...                   ...        ...       ...       ...        ...      ...
# 7470  PL/8528/EXP/ES/2015 -115.51610  32.65589      9656      16.79  regular
# 7471  PL/8697/EXP/ES/2015  -98.93101  19.41723      9657      17.60  regular
# 7472  PL/8719/EXP/ES/2015  -99.13486  19.44478      9658      18.31  regular
# 7473  PL/8382/EXP/ES/2015 -105.09400  20.82121      9659      19.69  regular
# 7474  PL/8482/EXP/ES/2015 -107.73920  29.35402      9660      19.54  regular
#
#      Rating User Ratings Google_Name Address Types
# 4983
# 4984
# 4985
# 4986
# 4987
# ...     ...          ...         ...     ...   ...
# 7470
# 7471
# 7472
# 7473
# 7474
#
# [2492 rows x 13 columns]

# %%
# Eduardo (Imported the files from resources)

part1 = "Resources/part1.csv"
part2 = "Resources/part2.csv"
part3 = "Resources/part3.csv"
part4 = "Resources/part4.csv"
part5 = "Resources/part5.csv"
part1_df = pd.read_csv(part1)
part2_df = pd.read_csv(part2)
part3_df = pd.read_csv(part3)
part4_df = pd.read_csv(part4)
part5_df = pd.read_csv(part5)

# %%
# Concatinate all of the DataFrames into one

Frames = [part1_df,part2_df,part3_df,part4_df,part5_df]
Mexico_Gas_Stations = pd.concat(Frames)
Mexico_Gas_Stations
# Out:
#       Unnamed: 0  index                                         name  \
# 0              0      0   ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.
# 1              1      3                 DIGEPE, S.A. DE C.V. (07356)
# 2              2      6                       DIAZ GAS, S.A. DE C.V.
# 3              3      8                  COMBU-EXPRESS, S.A. DE C.V.
# 4              4     11                       PETROMAX, S.A. DE C.V.
# ...          ...    ...                                          ...
# 2488       12455  33200                  MEGA GASOLINERAS S.A DE C.V
# 2489       12456  33203          GRUPO ENERGETICO GUDE, S.A. DE C.V.
# 2490       12457  33206                  MEGA GASOLINERAS S.A DE C.V
# 2491       12458  33209  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV
# 2492       12459  33212                      JAGREGAS 2 S.A. DE C.V.
#
#                     cre_id        Lng       Lat  place_id  gas_price gas type  \
# 0       PL/658/EXP/ES/2015 -116.92140  32.47641      2039      17.39  regular
# 1       PL/902/EXP/ES/2015  -99.74484  20.30370      2040      18.65  regular
# 2       PL/760/EXP/ES/2015 -106.45140  31.71947      2041      12.82  regular
# 3       PL/825/EXP/ES/2015 -103.30420  20.71413      2042      18.64  regular
# 4       PL/585/EXP/ES/2015  -98.29977  26.03787      2043      14.79  regular
# ...                    ...        ...       ...       ...        ...      ...
# 2488  PL/23515/EXP/ES/2020 -101.34460  20.72499     27295      18.79  regular
# 2489  PL/23507/EXP/ES/2020 -102.88500  23.16178     27298      18.15  regular
# 2490  PL/23513/EXP/ES/2020 -101.36640  20.68246     27299      18.25  regular
# 2491  PL/23508/EXP/ES/2020 -103.40990  22.83751     27300      17.89  regular
# 2492  PL/23510/EXP/ES/2020 -100.41290  20.67198     27304      16.99  regular
#
#       Rating  User Ratings                     Google_Name  \
# 0        4.3           3.0                Gasolinera Pemex
# 1        3.9          13.0                           Pemex
# 2        4.3         261.0                        TotalGas
# 3        4.0         105.0                Gasolinera Pemex
# 4        4.0          10.0                        Petromax
# ...      ...           ...                             ...
# 2488     3.0           2.0          Servicio Independencia
# 2489     4.7           3.0                          GUDE 4
# 2490     2.0           1.0  Gasolineros Unidos de Irapuato
# 2491     3.5           2.0          Grupo Gasolinero Rivas
# 2492     4.0           8.0                      JAGREGAS 2
#
#                                                 Address  \
# 0     Av de los Insurgentes No. 1910, Libramiento, T...
# 1         Carrt. Pachuca-Queretaro Km 58+500, Huichapan
# 2            Av. López Mateos 1604, La Plata, Cd Juárez
# 3     Perif. Nte. Ricardo Flores Magón Ote. No. 950,...
# 4     Río Purificación 800, Luis Donaldo Colosio Mur...
# ...                                                 ...
# 2488                                  Ave Siglo XXI 700
# 2489                                          Fresnillo
# 2490  Héroes de Nacozari S/N, Nuevos Colonos Unidos,...
# 2491                    Ranchito de la Cruz, Valparaíso
# 2492  Anillo Vial Fray Junípero Serra 102, Santiago ...
#
#                                               Types
# 0     gas_station, point_of_interest, establishment
# 1     gas_station, point_of_interest, establishment
# 2     gas_station, point_of_interest, establishment
# 3     gas_station, point_of_interest, establishment
# 4     gas_station, point_of_interest, establishment
# ...                                             ...
# 2488  gas_station, point_of_interest, establishment
# 2489  gas_station, point_of_interest, establishment
# 2490  gas_station, point_of_interest, establishment
# 2491  gas_station, point_of_interest, establishment
# 2492  gas_station, point_of_interest, establishment
#
# [12460 rows x 14 columns]

# %%
#Looking for missings
Mexico_Gas_Stations.isna().sum()/len(Mexico_Gas_Stations)
# Out:
# Unnamed: 0      0.000000
# index           0.000000
# name            0.000000
# cre_id          0.000000
# Lng             0.000000
# Lat             0.000000
# place_id        0.000000
# gas_price       0.000000
# gas type        0.000000
# Rating          0.001926
# User Ratings    0.001926
# Google_Name     0.001926
# Address         0.001926
# Types           0.001926
# dtype: float64

# %%
# 24 missing values, let's see just in user ratings, rating google name and address
Mexico_Gas_Stations_nas = Mexico_Gas_Stations[Mexico_Gas_Stations['Rating'].isna()]

Mexico_Gas_Stations_nas
# Out:
#       Unnamed: 0  index                                           name  \
# 1142        3633   9662               SOLUCIONES P&L, S.A.P.I. DE C.V.
# 1172        3663   9740                  SERVICIOS ABBA DEL FUERTE S A
# 1182        3673   9764               SOLUCIONES P&L, S.A.P.I. DE C.V.
# 1292        3783  10044            ESTACION DE SERVICIO TEIKA SA DE CV
# 2351        4842  12842               SOLUCIONES P&L, S.A.P.I. DE C.V.
# 2473        4964  13163               SOLUCIONES P&L, S.A.P.I. DE C.V.
# 217         5200  13798      GRUPO IMPULSORA MOCTEZUMA SPR DE RL DE CV
# 167        10134  26822                       GASOLINERA SIMON BOLIVAR
# 213        10180  26943                       MAXIMIANO ALVAREZ AMADOR
# 407        10374  27452                   ALCA ENERGETICA, S.A. DE C.V
# 913        10880  28761                      FUTUROVISION S.A. DE C.V.
# 921        10888  28784                   GERMAN PABLO RIVERA GONZALEZ
# 1674       11641  30919  SERVICIOS GASOLINEROS DE MEXICO, S.A. DE C.V.
# 1678       11645  30931  SERVICIOS GASOLINEROS DE MEXICO, S.A. DE C.V.
# 1688       11655  30960  GRUPO ENERGETICO DE LA CHONTALPA S.A. DE C.V.
# 1697       11664  30985                CARBURANTES DE YUCATAN SA DE CV
# 1698       11665  30987  SERVICIOS GASOLINEROS DE MEXICO, S.A. DE C.V.
# 1721       11688  31054               INMOBILIARIA HOTELA S.A. DE C.V.
# 1727       11694  31072          SERVICIOS KANASIN, SA DE CV (ES10633)
# 1763       11730  31175                          CHIKRI ABIMERHI BODIB
# 1827       11794  31361                    COMBU-EXPRESS, S.A. DE C.V.
# 1854       11821  31436                  SERVICIO GALUPE, S.A. DE C.V.
# 2056       12023  32001          COMBUSTIBLES DE ORIENTE, S.A. DE C.V.
# 2432       12399  33044   CORPORATIVO DE ESTACIONES ALCE, S.A. DE C.V.
#
#                     cre_id           Lng         Lat  place_id  gas_price  \
# 1142   PL/4659/EXP/ES/2015      19.41447   -99.03223      5812      18.55
# 1172   PL/3417/EXP/ES/2015    -108.37380    26.41212      5842      19.75
# 1182   PL/4663/EXP/ES/2015      19.38820   -99.02986      5852      18.55
# 1292   PL/3287/EXP/ES/2015    -104.52840    28.41779      5962      18.79
# 2351   PL/4713/EXP/ES/2015      19.48694   -99.03712      7024      18.69
# 2473   PL/4664/EXP/ES/2015      19.35144   -98.85688      7146      18.49
# 217    PL/3800/EXP/ES/2015    -104.60030    28.87011      7382      17.99
# 167   PL/11420/EXP/ES/2015    -103.22770    24.68618     13558      19.99
# 213   PL/11388/EXP/ES/2015    -111.30150    24.49053     13644      20.40
# 407   PL/12011/EXP/ES/2015     -88.13531    29.69880     14043      18.99
# 913   PL/13547/EXP/ES/2016    -110.97380    29.08580     16083      20.49
# 921   PL/13606/EXP/ES/2016    -109.01720    26.41003     16176      19.79
# 1674  PL/20494/EXP/ES/2017     101.59870    21.07213     23170      18.89
# 1678  PL/20499/EXP/ES/2017     101.49000    20.98868     23177      19.89
# 1688  PL/20540/EXP/ES/2017      93.20781    18.29521     23219      18.10
# 1697  PL/20576/EXP/ES/2017      89.56924    21.01828     23282      19.04
# 1698  PL/20585/EXP/ES/2017     101.79250    21.04617     23283      19.38
# 1721  PL/20670/EXP/ES/2017  355773.10000  2272.49000     23393      17.99
# 1727  PL/20677/EXP/ES/2017      89.41232    21.00008     23400      19.04
# 1763  PL/20843/EXP/ES/2018      89.56722    20.95430     23981      19.09
# 1827  PL/21004/EXP/ES/2018     103.44390    19.63984     24164      19.44
# 1854  PL/21031/EXP/ES/2018      88.56995    19.60969     24191      19.19
# 2056  PL/21722/EXP/ES/2018     -97.56774    25.91452     24965      14.99
# 2432  PL/23212/EXP/ES/2020    -116.61420    23.37432     26924      17.49
#
#      gas type  Rating  User Ratings Google_Name Address Types
# 1142  regular     NaN           NaN         NaN     NaN   NaN
# 1172  regular     NaN           NaN         NaN     NaN   NaN
# 1182  regular     NaN           NaN         NaN     NaN   NaN
# 1292  regular     NaN           NaN         NaN     NaN   NaN
# 2351  regular     NaN           NaN         NaN     NaN   NaN
# 2473  regular     NaN           NaN         NaN     NaN   NaN
# 217   regular     NaN           NaN         NaN     NaN   NaN
# 167   regular     NaN           NaN         NaN     NaN   NaN
# 213   regular     NaN           NaN         NaN     NaN   NaN
# 407   regular     NaN           NaN         NaN     NaN   NaN
# 913   premium     NaN           NaN         NaN     NaN   NaN
# 921   regular     NaN           NaN         NaN     NaN   NaN
# 1674   diesel     NaN           NaN         NaN     NaN   NaN
# 1678  premium     NaN           NaN         NaN     NaN   NaN
# 1688  regular     NaN           NaN         NaN     NaN   NaN
# 1697  regular     NaN           NaN         NaN     NaN   NaN
# 1698  regular     NaN           NaN         NaN     NaN   NaN
# 1721  regular     NaN           NaN         NaN     NaN   NaN
# 1727  regular     NaN           NaN         NaN     NaN   NaN
# 1763  regular     NaN           NaN         NaN     NaN   NaN
# 1827  regular     NaN           NaN         NaN     NaN   NaN
# 1854  regular     NaN           NaN         NaN     NaN   NaN
# 2056  regular     NaN           NaN         NaN     NaN   NaN
# 2432  regular     NaN           NaN         NaN     NaN   NaN

# %%
# duplicates
duplicated = Mexico_Gas_Stations[["Lng","Lat"]].duplicated().sum()
duplicated
# Out:
# 1

# %%
# identifying 
duplicated_station = Mexico_Gas_Stations.loc[Mexico_Gas_Stations[["name","Lat","Lng"]].duplicated(),"name"]
duplicated_station
# Out:
# 2230    ADMINISTRADORA DEL COLORADO S. DE R.L. DE C.V.
# Name: name, dtype: object

# %%
# drop duplicted
Mexico_Gas_Stations2 = Mexico_Gas_Stations.drop_duplicates()
Mexico_Gas_Stations2.tail()
# Out:
#       Unnamed: 0  index                                         name  \
# 2488       12455  33200                  MEGA GASOLINERAS S.A DE C.V
# 2489       12456  33203          GRUPO ENERGETICO GUDE, S.A. DE C.V.
# 2490       12457  33206                  MEGA GASOLINERAS S.A DE C.V
# 2491       12458  33209  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV
# 2492       12459  33212                      JAGREGAS 2 S.A. DE C.V.
#
#                     cre_id       Lng       Lat  place_id  gas_price gas type  \
# 2488  PL/23515/EXP/ES/2020 -101.3446  20.72499     27295      18.79  regular
# 2489  PL/23507/EXP/ES/2020 -102.8850  23.16178     27298      18.15  regular
# 2490  PL/23513/EXP/ES/2020 -101.3664  20.68246     27299      18.25  regular
# 2491  PL/23508/EXP/ES/2020 -103.4099  22.83751     27300      17.89  regular
# 2492  PL/23510/EXP/ES/2020 -100.4129  20.67198     27304      16.99  regular
#
#       Rating  User Ratings                     Google_Name  \
# 2488     3.0           2.0          Servicio Independencia
# 2489     4.7           3.0                          GUDE 4
# 2490     2.0           1.0  Gasolineros Unidos de Irapuato
# 2491     3.5           2.0          Grupo Gasolinero Rivas
# 2492     4.0           8.0                      JAGREGAS 2
#
#                                                 Address  \
# 2488                                  Ave Siglo XXI 700
# 2489                                          Fresnillo
# 2490  Héroes de Nacozari S/N, Nuevos Colonos Unidos,...
# 2491                    Ranchito de la Cruz, Valparaíso
# 2492  Anillo Vial Fray Junípero Serra 102, Santiago ...
#
#                                               Types
# 2488  gas_station, point_of_interest, establishment
# 2489  gas_station, point_of_interest, establishment
# 2490  gas_station, point_of_interest, establishment
# 2491  gas_station, point_of_interest, establishment
# 2492  gas_station, point_of_interest, establishment

# %%
# we eliminate 24 missing values to get 12,435 gas stations
Mexico_Gas_Stations3 = Mexico_Gas_Stations2.dropna()
Mexico_Gas_Stations3
# Out:
#       Unnamed: 0  index                                         name  \
# 0              0      0   ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.
# 1              1      3                 DIGEPE, S.A. DE C.V. (07356)
# 2              2      6                       DIAZ GAS, S.A. DE C.V.
# 3              3      8                  COMBU-EXPRESS, S.A. DE C.V.
# 4              4     11                       PETROMAX, S.A. DE C.V.
# ...          ...    ...                                          ...
# 2488       12455  33200                  MEGA GASOLINERAS S.A DE C.V
# 2489       12456  33203          GRUPO ENERGETICO GUDE, S.A. DE C.V.
# 2490       12457  33206                  MEGA GASOLINERAS S.A DE C.V
# 2491       12458  33209  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV
# 2492       12459  33212                      JAGREGAS 2 S.A. DE C.V.
#
#                     cre_id        Lng       Lat  place_id  gas_price gas type  \
# 0       PL/658/EXP/ES/2015 -116.92140  32.47641      2039      17.39  regular
# 1       PL/902/EXP/ES/2015  -99.74484  20.30370      2040      18.65  regular
# 2       PL/760/EXP/ES/2015 -106.45140  31.71947      2041      12.82  regular
# 3       PL/825/EXP/ES/2015 -103.30420  20.71413      2042      18.64  regular
# 4       PL/585/EXP/ES/2015  -98.29977  26.03787      2043      14.79  regular
# ...                    ...        ...       ...       ...        ...      ...
# 2488  PL/23515/EXP/ES/2020 -101.34460  20.72499     27295      18.79  regular
# 2489  PL/23507/EXP/ES/2020 -102.88500  23.16178     27298      18.15  regular
# 2490  PL/23513/EXP/ES/2020 -101.36640  20.68246     27299      18.25  regular
# 2491  PL/23508/EXP/ES/2020 -103.40990  22.83751     27300      17.89  regular
# 2492  PL/23510/EXP/ES/2020 -100.41290  20.67198     27304      16.99  regular
#
#       Rating  User Ratings                     Google_Name  \
# 0        4.3           3.0                Gasolinera Pemex
# 1        3.9          13.0                           Pemex
# 2        4.3         261.0                        TotalGas
# 3        4.0         105.0                Gasolinera Pemex
# 4        4.0          10.0                        Petromax
# ...      ...           ...                             ...
# 2488     3.0           2.0          Servicio Independencia
# 2489     4.7           3.0                          GUDE 4
# 2490     2.0           1.0  Gasolineros Unidos de Irapuato
# 2491     3.5           2.0          Grupo Gasolinero Rivas
# 2492     4.0           8.0                      JAGREGAS 2
#
#                                                 Address  \
# 0     Av de los Insurgentes No. 1910, Libramiento, T...
# 1         Carrt. Pachuca-Queretaro Km 58+500, Huichapan
# 2            Av. López Mateos 1604, La Plata, Cd Juárez
# 3     Perif. Nte. Ricardo Flores Magón Ote. No. 950,...
# 4     Río Purificación 800, Luis Donaldo Colosio Mur...
# ...                                                 ...
# 2488                                  Ave Siglo XXI 700
# 2489                                          Fresnillo
# 2490  Héroes de Nacozari S/N, Nuevos Colonos Unidos,...
# 2491                    Ranchito de la Cruz, Valparaíso
# 2492  Anillo Vial Fray Junípero Serra 102, Santiago ...
#
#                                               Types
# 0     gas_station, point_of_interest, establishment
# 1     gas_station, point_of_interest, establishment
# 2     gas_station, point_of_interest, establishment
# 3     gas_station, point_of_interest, establishment
# 4     gas_station, point_of_interest, establishment
# ...                                             ...
# 2488  gas_station, point_of_interest, establishment
# 2489  gas_station, point_of_interest, establishment
# 2490  gas_station, point_of_interest, establishment
# 2491  gas_station, point_of_interest, establishment
# 2492  gas_station, point_of_interest, establishment
#
# [12436 rows x 14 columns]

# %%
Mexico_Gas_Stations3.describe()
# Out:
#          Unnamed: 0         index           Lng           Lat      place_id  \
# count  12436.000000  12436.000000  12436.000000  12436.000000  12436.000000
# mean    6223.539482  16493.477565   -101.111736     22.362393   9767.510293
# std     3594.994745   9534.399690      8.734461      4.167085   6209.721509
# min        0.000000      0.000000   -117.120200     14.672430   2039.000000
# 25%     3108.750000   8274.250000   -103.455025     19.397077   5283.750000
# 50%     6224.500000  16505.500000   -100.366150     20.685200   8407.500000
# 75%     9333.250000  24706.750000    -98.421830     25.553805  11668.250000
# max    12459.000000  33212.000000    108.092100     32.716290  27304.000000
#
#           gas_price        Rating  User Ratings
# count  12436.000000  12436.000000  12436.000000
# mean      18.392517      3.295360     54.468318
# std        1.393100      1.487949    110.470165
# min        0.010000      0.000000      0.000000
# 25%       17.890000      3.400000      2.000000
# 50%       18.590000      3.800000     17.000000
# 75%       19.200000      4.100000     61.000000
# max       25.050000      5.000000   2374.000000

# %% [markdown]
#  # Statistical Analysis

# %%
countby_type_df = Mexico_Gas_Stations3.groupby(Mexico_Gas_Stations3["gas type"]).count()["cre_id"].to_frame()

countby_type_df
# Out:
#           cre_id
# gas type
# diesel       821
# premium      753
# regular    10862

# %%
countby_type_df.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='gas type'>

# %%
plt.hist(Mexico_Gas_Stations3["Rating"])
plt.title("Rating Distribution 12,436 Gas Stations")
plt.xlabel('Rating')
plt.ylabel('Counts')
plt.show()

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Rating Distribution')
ax1.set_ylabel('Rating')
ax1.boxplot(Mexico_Gas_Stations3["Rating"])
plt.show()

# %%
plt.hist(Mexico_Gas_Stations3["gas_price"])
plt.title("Price Distribution 12,436 Gas Stations")
plt.xlabel('Rating')
plt.ylabel('Counts')
plt.show()

# %%
plt.hist(Mexico_Gas_Stations3["User Ratings"])
plt.title("User Ratings Distribution 12,436 Gas Stations")
plt.xlabel('Rating')
plt.ylabel('Counts')
plt.show()

# %%
Mexico_Gas_Stations4["User Ratings"].describe()
# Out:
# count    12423.000000
# mean        54.525155
# std        110.513972
# min          0.000000
# 25%          2.000000
# 50%         17.000000
# 75%         61.500000
# max       2374.000000
# Name: User Ratings, dtype: float64

# %%
Mexico_Gas_Stations4["User Ratings"].median()
# Out:
# 17.0

# %%
ratings = Mexico_Gas_Stations4.loc[Mexico_Gas_Stations4["User Ratings"] > 0]
len(ratings)
# Out:
# 10620

# %%
quartiles = ratings["User Ratings"].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 6.0
# The upper quartile of temperatures is: 74.0
# The interquartile range of temperatures is: 68.0
# The the median of temperatures is: 26.0
# Values below -96.0 could be outliers.
# Values above 176.0 could be outliers.

# %%
#beans (Sam) tomar las reseñas mayores a cero.
Mexico_Gas_Stations4 = ratings.loc[ratings["Lng"]<=50]
plt.figure(figsize=(5, 5), dpi=120)
plt.scatter(ratings["Lng"],ratings["Lat"], edgecolor="green", alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sub = ratings.loc[ratings["Rating"] >= 4]

# %%
# %matplotlib notebook
plt.figure(figsize=(10, 8), dpi=120)
plt.hexbin(sub["Lng"],sub["Lat"], C=sub["Rating"])
cb=plt.colorbar()
cb.set_label("Rating")
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
countby_type_df = Gas_Stations_df.groupby(Gas_Stations_df["type"]).count()["place_id"].to_frame()
countby_type_df = countby_type_df.rename(columns={"place_id":"Stations"})
countby_type_df
# Out:
#          Stations
# type
# diesel       9271
# premium     11552
# regular     12392

# %%
regular_gas = Gas_Stations_df.loc[Gas_Stations_df["type"]=="regular"]
premium_gas = Gas_Stations_df.loc[Gas_Stations_df["type"]=="premium"]
diesel_gas = Gas_Stations_df.loc[Gas_Stations_df["type"]=="diesel"]

# %%
lng_regular_gas = regular_gas["lng"]
lat_regular_gas = regular_gas["lat"]
lng_premium_gas = premium_gas["lng"]
lat_premium_gas = premium_gas["lat"]
lng_diesel_gas = diesel_gas["lng"]
lat_diesel_gas = diesel_gas["lat"]

# %%
premium_gas.head()
# Out:
#                                           name              cre_id        lng  \
# 1   ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.  PL/658/EXP/ES/2015 -116.92140
# 4                 DIGEPE, S.A. DE C.V. (07356)  PL/902/EXP/ES/2015  -99.74484
# 7                       DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015 -106.45140
# 9                  COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015 -103.30420
# 12                      PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  -98.29977
#
#          lat  place_id  gas_price     type
# 1   32.47641      2039      19.35  premium
# 4   20.30370      2040      18.99  premium
# 7   31.71947      2041      13.59  premium
# 9   20.71413      2042      19.39  premium
# 12  26.03787      2043      16.39  premium

# %%
diesel_gas.head()
# Out:
#                                           name              cre_id        lng  \
# 2   ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.  PL/658/EXP/ES/2015 -116.92140
# 5                 DIGEPE, S.A. DE C.V. (07356)  PL/902/EXP/ES/2015  -99.74484
# 10                 COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015 -103.30420
# 15         MULTISERVICIOS LA PILARICA SA DE CV  PL/371/EXP/ES/2015 -108.96850
# 20                      PETROMAX, S.A. DE C.V.  PL/439/EXP/ES/2015 -100.29180
#
#          lat  place_id  gas_price    type
# 2   32.47641      2039      18.45  diesel
# 5   20.30370      2040      18.89  diesel
# 10  20.71413      2042      18.74  diesel
# 15  25.75580      2045      19.99  diesel
# 20  25.77202      2046      19.49  diesel

# %%
regular_gas.head()
# Out:
#                                           name              cre_id        lng  \
# 0   ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.  PL/658/EXP/ES/2015 -116.92140
# 3                 DIGEPE, S.A. DE C.V. (07356)  PL/902/EXP/ES/2015  -99.74484
# 6                       DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015 -106.45140
# 8                  COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015 -103.30420
# 11                      PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  -98.29977
#
#          lat  place_id  gas_price     type
# 0   32.47641      2039      17.39  regular
# 3   20.30370      2040      18.65  regular
# 6   31.71947      2041      12.82  regular
# 8   20.71413      2042      18.64  regular
# 11  26.03787      2043      14.79  regular

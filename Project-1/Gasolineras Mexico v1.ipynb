# %%
# Dependencies
import pandas as pd
import numpy as np
from numpy import NaN
import matplotlib.pyplot as plt

# %%
def listToString(s):  
    
    # initialize an empty string 
    str1 = " " 
    
    # return string   
    return (str1.join(s))

# %%
# Extracting Data from CSV to Jupyter-Notebook
prices_file = "Resources/prices.csv"
places_file = "Resources/places.csv"
prices_df = pd.read_csv(prices_file)
places_df = pd.read_csv(places_file)

# %%
# Cleaning Columns on Prices DataFrame
prices_df = prices_df.drop('places', axis = 1)
prices_df = prices_df.drop('place', axis = 1)
prices_df
# Out:
#        place_id  gas_price     type
# 0       11703.0      18.69  regular
# 1           NaN      19.69  premium
# 2       11702.0      18.19  regular
# 3           NaN      19.79  premium
# 4           NaN      18.25   diesel
# ...         ...        ...      ...
# 33210       NaN      19.59  premium
# 33211       NaN      18.60   diesel
# 33212    2807.0      17.99  regular
# 33213    2807.0      19.99  premium
# 33214    2807.0      18.69   diesel
#
# [33215 rows x 3 columns]

# %%
# Creating a column to replace NaNs with Places_ID
Place_ID = prices_df['place_id'].fillna(method='ffill')
# Adding Column to existing prices DataFrame
prices_df['Place_ID'] = Place_ID
# Eliminating original place_id from DataFrame
prices_df = prices_df.drop('place_id', axis = 1)
# Rearrange DataFrame
prices_df = prices_df[['Place_ID','gas_price','type']]
# Rename Place_ID
prices_df.columns = ['place_id', 'gas_price','type']
prices_df
# Out:
#        _place_id  gas_price     type
# 0        11703.0      18.69  regular
# 1        11703.0      19.69  premium
# 2        11702.0      18.19  regular
# 3        11702.0      19.79  premium
# 4        11702.0      18.25   diesel
# ...          ...        ...      ...
# 33210    11704.0      19.59  premium
# 33211    11704.0      18.60   diesel
# 33212     2807.0      17.99  regular
# 33213     2807.0      19.99  premium
# 33214     2807.0      18.69   diesel
#
# [33215 rows x 3 columns]

# %%
# Merging DataFrames
Gas_Stations_df = pd.merge(places_df, prices_df, on="_place_id")
Gas_Stations_df
# Out:
#                                               name                cre_id  \
# 0       ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.    PL/658/EXP/ES/2015
# 1       ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.    PL/658/EXP/ES/2015
# 2       ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.    PL/658/EXP/ES/2015
# 3                     DIGEPE, S.A. DE C.V. (07356)    PL/902/EXP/ES/2015
# 4                     DIGEPE, S.A. DE C.V. (07356)    PL/902/EXP/ES/2015
# ...                                            ...                   ...
# 33210  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV  PL/23508/EXP/ES/2020
# 33211  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV  PL/23508/EXP/ES/2020
# 33212                      JAGREGAS 2 S.A. DE C.V.  PL/23510/EXP/ES/2020
# 33213                      JAGREGAS 2 S.A. DE C.V.  PL/23510/EXP/ES/2020
# 33214                      JAGREGAS 2 S.A. DE C.V.  PL/23510/EXP/ES/2020
#
#        location/x  location/y  _place_id  gas_price     type
# 0      -116.92140    32.47641       2039      17.39  regular
# 1      -116.92140    32.47641       2039      19.35  premium
# 2      -116.92140    32.47641       2039      18.45   diesel
# 3       -99.74484    20.30370       2040      18.65  regular
# 4       -99.74484    20.30370       2040      18.99  premium
# ...           ...         ...        ...        ...      ...
# 33210  -103.40990    22.83751      27300      18.59  premium
# 33211  -103.40990    22.83751      27300      18.89   diesel
# 33212  -100.41290    20.67198      27304      16.99  regular
# 33213  -100.41290    20.67198      27304      17.30  premium
# 33214  -100.41290    20.67198      27304      17.41   diesel
#
# [33215 rows x 7 columns]

# %%
# Process to get complementary information from google maps API
import requests
import json

# Google developer API key
from config import gkey

# %%
# Preparing API Call from google using iterrow() method
original = pd.read_csv("../Project-1/Resources/Places.csv")

# Let's try with variables relevants for the call
Gas_Stations = original.loc[:, ["name", "_place_id", "location/x", "location/y"]]

# Add a "Hotel Name" column to the DataFrame.
Gas_Stations["rating"] = ""
Gas_Stations.rename(columns={"name":"Name", "cre_id":"ID", "location/x":"Lng", "location/y":"Lat", "rating":"Rating"}, inplace=True)
Gas_Stations
# Getting a subset to proof
Gas_Stations_sub = Gas_Stations.head()
Gas_Stations_sub
# Out:
#                                          Name  _place_id        Lng       Lat  \
# 0  ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.       2039 -116.92140  32.47641
# 1                DIGEPE, S.A. DE C.V. (07356)       2040  -99.74484  20.30370
# 2                      DIAZ GAS, S.A. DE C.V.       2041 -106.45140  31.71947
# 3                 COMBU-EXPRESS, S.A. DE C.V.       2042 -103.30420  20.71413
# 4                      PETROMAX, S.A. DE C.V.       2043  -98.29977  26.03787
#
#   Rating
# 0
# 1
# 2
# 3
# 4

# %%
A = Gas_Stations_df.drop_duplicates(subset="_place_id").reset_index(drop=False)
A.iloc[1363]
# Out:
# index                                        3599
# name          Gasolinería Recoletos, S.A. de C.V.
# cre_id                        PL/1742/EXP/ES/2015
# location/x                               -99.0275
# location/y                                19.5329
# _place_id                                    3418
# gas_price                                   18.99
# type                                      regular
# Name: 1363, dtype: object

# %%
Gas_Stations[""]

# %%
rating = Gas_Stations_sub.loc[:,['Name', 'Lat', 'Lng', 'Rating']]
rating = pd.DataFrame(rating)
Gas_Stations["Rating"] = ""
Gas_Stations["User Ratings"] ="" 
Gas_Stations["Google_Name"] = ""
Gas_Stations["Address"]= ""
Gas_Stations["Types"]= ""
Gas_Stations.head()
# Out:
#                                          Name                  ID        Lng  \
# 0  ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.  PL/658/EXP/ES/2015 -116.92140
# 1                DIGEPE, S.A. DE C.V. (07356)  PL/902/EXP/ES/2015  -99.74484
# 2                      DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015 -106.45140
# 3                 COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015 -103.30420
# 4                      PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  -98.29977
#
#         Lat Rating User Ratings Google_Name Address Types
# 0  32.47641
# 1  20.30370
# 2  31.71947
# 3  20.71413
# 4  26.03787

# %%
params = {
    "rankby":"distance",
    "type": "gas_station",
    "keyword": "fuel station",
    "key": gkey    
}

# Hit the Google Places API for each city's coordinates.
url_base = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
# Store the first Hotel result into the DataFrame.
for index, row in Gas_Stations.iloc[1363:1365].iterrows():
    lat=row["Lat"]
    lon=row["Lng"]
        
    params["location"] = f"{lat},{lon}"
    
    print(f"Results for observation: {index}")
    try:
        response = requests.get(url_base, params=params).json()
        Gas_Stations.loc[index, "Rating"] = response["results"][0]["rating"]
        Gas_Stations.loc[index, "User Ratings"] = response["results"][0]["user_ratings_total"]
        Gas_Stations.loc[index, "Google_Name"] = response["results"][0]["name"]
        Gas_Stations.loc[index, "Address"] = response["results"][0]["vicinity"]
        string = response["results"][0]["types"]
        string_value = listToString(string)
        string_value = string_value.replace(" ",", ")
        Gas_Stations.loc[index, "Types"] = string_value
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

# To storage the requests

    results = response['results']
# Out:
# Results for observation: 1363
# Missing field/result... skipping.
# Results for observation: 1364
# Missing field/result... skipping.

# %%
Gas_Stations
# Out:
#                                               Name  _place_id        Lng  \
# 0       ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.       2039 -116.92140
# 1                     DIGEPE, S.A. DE C.V. (07356)       2040  -99.74484
# 2                           DIAZ GAS, S.A. DE C.V.       2041 -106.45140
# 3                      COMBU-EXPRESS, S.A. DE C.V.       2042 -103.30420
# 4                           PETROMAX, S.A. DE C.V.       2043  -98.29977
# ...                                            ...        ...        ...
# 12748  GRUPO GASOLINERO DEL DIAMANTE HOLZ SA DE CV      27300 -103.40990
# 12749                  MEGA GASOLINERAS S.A DE C.V      27301 -101.70620
# 12750    GRUPO OCCIDENTAL DE COMBUSTIBLES SA DE CV      27302 -103.73400
# 12751                      MARCOS GOMEZ MONTENEGRO      27303  -98.87885
# 12752                      JAGREGAS 2 S.A. DE C.V.      27304 -100.41290
#
#             Lat Rating
# 0      32.47641
# 1      20.30370
# 2      31.71947
# 3      20.71413
# 4      26.03787
# ...         ...    ...
# 12748  22.83751
# 12749  21.08131
# 12750  19.23678
# 12751  18.94553
# 12752  20.67198
#
# [12753 rows x 5 columns]

# %%
test = response["results"][0]["types"] #validación if
# Out:
# 'gas_station, point_of_interest, establishment'

# %%
# Paths to get the info in json responses

response["results"][0]["geometry"]["location"]["lat"] 
response["results"][0]["geometry"]["location"]["lng"]
response["results"][0]["rating"]
response["results"][0]["name"]
response["results"][0]["user_ratings_total"]
response["results"][0]["vicinity"]
response["results"][0]["types"]
# Out:
# ['gas_station', 'point_of_interest', 'establishment']

# %%
response["results"][0]["rating"]
# Out:
# 4.6

# %%
rating ["lat"] =""
rating["lng"] = ""
rating["name"] = ""
rating["user_rating_total"] = ""
rating["types"] = ""
rating["vicinity"]= ""
rating
# Out:
#                                          Name       Lat        Lng Rating lat  \
# 0  ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.  32.47641 -116.92140
# 1                DIGEPE, S.A. DE C.V. (07356)  20.30370  -99.74484
# 2                      DIAZ GAS, S.A. DE C.V.  31.71947 -106.45140
# 3                 COMBU-EXPRESS, S.A. DE C.V.  20.71413 -103.30420
# 4                      PETROMAX, S.A. DE C.V.  26.03787  -98.29977
#
#   lng name user_rating_total types vicinity
# 0
# 1
# 2
# 3
# 4
